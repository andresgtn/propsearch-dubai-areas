# %% [markdown]
# ## Merge area lists from Propsearch.com into a single list
#
# Having scrapped area lists containing all projects/buildings in each from propsearch which have been saved in separate files and lists, we seek to merge all into a single list to classify by completion/development/hold/planned. This will help us inform which developers to contact for new and ongoing off-plan sales.
#
# This list will contain the following columns:
# * Link to the particular building/community on propsearch.com: link to Marina Gate 2
# * Building/project name: e.g. Marina Gate 2
# * Area: e.d. Dubai Marina
# * Completion stage: e.g. completed
#
# The list is saved as a csv file for further use.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import glob
import os

def preprocess_single_projects(path):
    '''
    Merge all csv files in the directory into single file
    
    Input: directory: directory name, not path, assumes this notebook is in the 
    '''
    # read in all file paths
    # assumes they are in the cwd
    path_list = glob.glob('./{}/*/*'.format(directory))
    
    # process paths into df
    projects_df = pd.DataFrame()
    for path in path_list:
        raw_df = pd.read_csv(os.path.abspath(path), index_col=False)
        if 'ps-loc-card-location' not in raw_df.columns:
            # extract location name from path
            added_location = path.split('/')[2].replace('-', ' ').title()
            # add area name to new column
            raw_df.insert(loc=0, column='ps-loc-card-location', value=added_location)
        # add custom area name column based on the name I used for each directory containing an area
        added_location = path.split('/')[2].replace('-', ' ').title() #todo
        raw_df.insert(loc=0, column='area', value=added_location) #todo
        projects_df = pd.concat([projects_df, raw_df], axis=0)
    
    # clean df
    #drop 'lazy src column'
    projects_df.drop(columns=['lazy src'], inplace=True)
    # reorder columns
    new_column_order = ['area', 'ps-loc-card-location', 'ps-loc-card-title', 
                        'ps-loc-card-status', 'tablescraper-selected-row href']
    projects_df = projects_df[new_column_order]
    # rename columns to simpler names
    renamed_columns = {'ps-loc-card-location': 'sub_area', 'ps-loc-card-title': 'project', 
                        'ps-loc-card-status': 'status', 'tablescraper-selected-row href': 'link'}
    projects_df.rename(columns=renamed_columns, inplace=True)
    # sort by area name
    projects_df.sort_values(by=['area'], inplace=True)
    # reset indices
    projects_df.reset_index(drop=True, inplace=True)
    
    return projects_df

# %%
# read and preprocess data into df containing all towers
directory = 'buildings_raw'
towers_df = preprocess_single_projects(directory)

# %%
# describe data
towers_df.describe()
# Out:
#                            area      sub_area     project    status  \
# count                      1576          1576        1576      1576
# unique                       13            57        1576        11
# top     Jumeirah Village Circle  Business Bay  Lana Tower  Complete
# freq                        498           201           1       934
#
#                                                 link
# count                                           1576
# unique                                          1576
# top     https://propsearch.ae/dubai/golden-wood-view
# freq                                               1

# %% [markdown]
# #### Save towers_df to csv

# %%
towers_df.to_csv('towers_df.csv', index=False)

# %% [markdown]
# #### Look at data an extract desired projects to look into

# %%
towers_df.head(3)
# Out:
#     area sub_area           project                           status  \
# 0  Arjan    Arjan  Dania Building 2                         Complete
# 1  Arjan    Arjan       Joya Blanca  Under development (In progress)
# 2  Arjan    Arjan        La Fontana                         Complete
#
#                                            link
# 0  https://propsearch.ae/dubai/dania-building-2
# 1       https://propsearch.ae/dubai/joya-blanca
# 2        https://propsearch.ae/dubai/la-fontana

# %%
# project count by status type
towers_df.status.value_counts()
# Out:
# Complete                             934
# Under development                    277
# Under development (Cancelled)        136
# Under development (On hold)          134
# Planned                               47
# Envisioned                            22
# Under development (In progress)       15
# Planned (Cancelled)                    5
# Under development (Progress slow)      3
# Demolished                             2
# Complete (Handover underway)           1
# Name: status, dtype: int64

# %%
# projects under development by area
on_dev_df = towers_df[towers_df.status == 'Under development']
on_dev_df.area.value_counts()
# Out:
# Jumeirah Village Circle      97
# Business Bay                 34
# Arjan                        32
# Jumeirah Village Triangle    22
# Downtown                     18
# Dubai Creek Harbour          17
# Palm Jumeirah                16
# Sobha Hartland               11
# Dubai Hills Estate           10
# Dubai Marina                  9
# Sports City                   7
# Jumeirah Lakes Towers         2
# Motor City                    2
# Name: area, dtype: int64

# %%
# projects under development in Business Bay
bbay_on_dev_df = on_dev_df[on_dev_df.area == 'Business Bay']
bbay_on_dev_df
# Out:
#              area         sub_area  \
# 96   Business Bay     Business Bay
# 98   Business Bay     Business Bay
# 99   Business Bay     Business Bay
# 108  Business Bay     Business Bay
# 110  Business Bay     Business Bay
# 118  Business Bay     Business Bay
# 121  Business Bay     Business Bay
# 133  Business Bay     Business Bay
# 134  Business Bay     Business Bay
# 140  Business Bay     Business Bay
# 144  Business Bay  Al Habtoor City
# 158  Business Bay     Business Bay
# 167  Business Bay     Business Bay
# 173  Business Bay     Business Bay
# 177  Business Bay     Business Bay
# 178  Business Bay     Business Bay
# 185  Business Bay     Business Bay
# 189  Business Bay     Business Bay
# 192  Business Bay     Business Bay
# 193  Business Bay     Business Bay
# 196  Business Bay     Business Bay
# 209  Business Bay     Business Bay
# 219  Business Bay     Business Bay
# 233  Business Bay     Business Bay
# 243  Business Bay     Business Bay
# 285  Business Bay     Business Bay
# 291  Business Bay     Business Bay
# 295  Business Bay     Business Bay
# 296  Business Bay     Business Bay
# 298  Business Bay     Business Bay
# 299  Business Bay     Business Bay
# 303  Business Bay     Business Bay
# 306  Business Bay     Business Bay
# 312  Business Bay     Business Bay
#
#                                          project             status  \
# 96               Millennium Binghatti Residences  Under development
# 98                                    Moon Tower  Under development
# 99                      Mövenpick Hotel & Living  Under development
# 108                     Nobles Residential Tower  Under development
# 110                            Marble Arch Tower  Under development
# 118                           Mama Shelter Dubai  Under development
# 121                                Lillian Tower  Under development
# 133                        AG Tower Business Bay  Under development
# 134                              Ahad Residences  Under development
# 140           Paramount Tower Hotel & Residences  Under development
# 144                                   Amna Tower  Under development
# 158                 Kingston Towers Business Bay  Under development
# 167                                Sky Bay Hotel  Under development
# 173                               Safeer Tower 3  Under development
# 177                Ritz Carlton Hotel Apartments  Under development
# 178                                Reva by Damac  Under development
# 185                      Ramee Grand Hotel & Spa  Under development
# 189               SRG Holding Hotel Business Bay  Under development
# 192                       Kempinski Business Bay  Under development
# 193                                  Kasco Tower  Under development
# 196                                        J One  Under development
# 209                              The Court Tower  Under development
# 219                   The One Hotel Business Bay  Under development
# 233                       Dorchester Hotel Dubai  Under development
# 243                                Dolphin Tower  Under development
# 285                               Bayz by Danube  Under development
# 291                          Corporate Bay Tower  Under development
# 295                          Tiara United Towers  Under development
# 296  Commercial & Residential Tower Plot 3460763  Under development
# 298                                   Zada Tower  Under development
# 299                                  Yotel Dubai  Under development
# 303                               West Bay Tower  Under development
# 306                              Waterfall Tower  Under development
# 312                                Vera by Damac  Under development
#
#                                                   link
# 96   https://propsearch.ae/dubai/millennium-binghat...
# 98              https://propsearch.ae/dubai/moon-tower
# 99   https://propsearch.ae/dubai/movenpick-hotel-li...
# 108  https://propsearch.ae/dubai/nobles-residential...
# 110      https://propsearch.ae/dubai/marble-arch-tower
# 118     https://propsearch.ae/dubai/mama-shelter-dubai
# 121          https://propsearch.ae/dubai/lillian-tower
# 133  https://propsearch.ae/dubai/ag-tower-business-bay
# 134        https://propsearch.ae/dubai/ahad-residences
# 140  https://propsearch.ae/dubai/paramount-tower-ho...
# 144             https://propsearch.ae/dubai/amna-tower
# 158  https://propsearch.ae/dubai/kingston-towers-bu...
# 167          https://propsearch.ae/dubai/sky-bay-hotel
# 173         https://propsearch.ae/dubai/safeer-tower-3
# 177  https://propsearch.ae/dubai/ritz-carlton-hotel...
# 178          https://propsearch.ae/dubai/reva-by-damac
# 185  https://propsearch.ae/dubai/ramee-grand-hotel-spa
# 189  https://propsearch.ae/dubai/srg-holding-hotel-...
# 192  https://propsearch.ae/dubai/kempinski-business...
# 193            https://propsearch.ae/dubai/kasco-tower
# 196                  https://propsearch.ae/dubai/j-one
# 209        https://propsearch.ae/dubai/the-court-tower
# 219  https://propsearch.ae/dubai/the-one-hotel-busi...
# 233  https://propsearch.ae/dubai/dorchester-hotel-d...
# 243          https://propsearch.ae/dubai/dolphin-tower
# 285         https://propsearch.ae/dubai/bayz-by-danube
# 291    https://propsearch.ae/dubai/corporate-bay-tower
# 295    https://propsearch.ae/dubai/tiara-united-towers
# 296  https://propsearch.ae/dubai/commercial-residen...
# 298             https://propsearch.ae/dubai/zada-tower
# 299            https://propsearch.ae/dubai/yotel-dubai
# 303         https://propsearch.ae/dubai/west-bay-tower
# 306        https://propsearch.ae/dubai/waterfall-tower
# 312          https://propsearch.ae/dubai/vera-by-damac

# %%
bbay_on_dev_df.link.iloc[0]
# Out:
# 'https://propsearch.ae/dubai/millennium-binghatti-residences'

# %%
towers_df.sub_area.unique()
# Out:
# array(['Jumeirah Lakes Towers', 'Sports City', 'Canal Residence West',
#        'Sobha Hartland', 'Sobha Hartland Greens', 'JVC District 15',
#        'JVC District 14', 'JVC District 12', 'JVC District 18',
#        'JVC District 11', 'JVC District 17', 'JVC District 10',
#        'JVC District 13', 'JVC District 16', 'Jumeirah Village Circle',
#        'Downtown Dubai', 'The Opera District', 'Yansoon', 'Zaafaran',
#        'Zanzabeel', 'Old Town', 'Kamoon', 'Miska', 'Reehan',
#        'Al Murooj Complex', 'Dubai Marina', 'Jumeirah Beach Residence',
#        'Bluewaters Island', 'Dubai Marina Mall', 'Bluewaters Residences',
#        'The Address Dubai Marina', 'Creek Island', 'Creek Beach',
#        'Dubai Creek Harbour', 'Uptown Motor City', 'Motor City',
#        'Green Community Motor City', 'Business Bay', 'Al Habtoor City',
#        'Bay Square', 'M Hotel Downtown by Millennium Dubai', 'Arjan',
#        'Palm Jumeirah', 'The Palm Crescent', 'The Golden Mile',
#        'Park Heights', 'Dubai Hills Estate', 'Dubai Hills Business Park',
#        'Park Ridge', 'JVT District 1', 'JVT District 6', 'JVT District 7',
#        'JVT District 2', 'JVT District 4', 'JVT District 3',
#        'Jumeirah Village Triangle', 'JVT District 5'], dtype=object)

# %%
towers_df.area.unique()
# Out:
# array(['Jumeirah Lakes Towers', 'Sports City', 'Sobha Hartland',
#        'Jumeirah Village Circle', 'Downtown', 'Dubai Marina',
#        'Dubai Creek Harbour', 'Motor City', 'Business Bay', 'Arjan',
#        'Palm Jumeirah', 'Dubai Hills Estate', 'Jumeirah Village Triangle'],
#       dtype=object)

# %% [markdown]
# ## Get gps coordinates and project tabled data for each project
#
# Using Beatutifulsoup to scrap each link on the project df
# * key information
# * companies-associated
# * milestones
# * proximity-to-landmarks
# * coordinates
#
# Scrapping inspiration from Datacamp [link](https://www.datacamp.com/community/tutorials/amazon-web-scraping-using-beautifulsoup?utm_source=adwords_ppc&utm_campaignid=898687156&utm_adgroupid=48947256715&utm_device=c&utm_keyword=&utm_matchtype=b&utm_network=g&utm_adpostion=&utm_creative=229765585183&utm_targetid=dsa-429603003980&utm_loc_interest_ms=&utm_loc_physical_ms=1000013&gclid=Cj0KCQjw0emHBhC1ARIsAL1QGNdx-wU43XjIPm2mfMWut-ceTSl2j3WZ7X8DiH4tl7mfG4njEnGfGYkaAuCiEALw_wcB) and Real Python [link](https://realpython.com/beautiful-soup-web-scraper-python/)

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests
import re

# %%
len(bbay_on_dev_df)
# Out:
# 34

# %%
import re

def get_last_photo_update(soup):
    # get string and link of last project photo update to check progress
    construction_updates = soup.find(id='jump-to-construction-updates')
    gallery = construction_updates.find('div', class_='fotorama ps-gallery-portrait')
    raw_caption = gallery.find('a')

    raw_caption = str(raw_caption)
    caption = re.search('data-caption="(.*) Image &amp;copy', raw_caption)
    caption = caption.group(1).replace('\"', '')
    photo_url = re.search('data-full=(.*) href=', raw_caption)
    photo_url = photo_url.group(1).replace('\"', '')
    return caption, photo_url

# %%
# alias for the dataframe containing the links to scrap
scrap_df = bbay_on_dev_df
# set bounds for urls to scrap
url_idx_start = 0
url_idx_end = len(scrap_df) + 1
# construct an iterable with the original index and the url
url_list = zip(list(scrap_df.link.iloc[url_idx_start:url_idx_end].index), 
               list(scrap_df.link.iloc[url_idx_start:url_idx_end]))
# instantiate dic to hold scrapped data
scrapped_dict = {}
# iterate over a list of urls
for url_key, url in url_list:
    # cast url_key as str to index the dictionary
    url_key = str(url_key)
    # set request header with appropriate permissions
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}
    # request url data
    r = requests.get(url, headers=headers)#, proxies=proxies)
    # get content
    content = r.content
    # parse content
    soup = BeautifulSoup(content, "html.parser")
    
    # add this entry to dictionary, using the same key as in the original dataframe index
    scrapped_dict[url_key] = {}
    # save the url
    scrapped_dict[url_key]['url'] = url
    # add space to save each table with info
    scrapped_dict[url_key]['tables'] = {}

    # get coordinates
    coordinates_div = soup.find('div', attrs={'class':'ps-guide-sub-subheading'})
    coordinates = coordinates_div.text.strip().replace('place', '').replace('\'', ' ')
    # add coordinates to dict
    scrapped_dict[url_key]['coordinates'] = coordinates
    
    # get las photo update
    try:
        caption, photo_url = get_last_photo_update(soup)
        scrapped_dict[url_key]['last_photo_update'] = {'caption': caption, 'photo_url': photo_url}
    except:
        print('Failed to get photo update for: {}'.format(url))
        pass

    # get tables with contents
    kv_list = soup.findAll('div', class_='ps-kv-list')
    # iterate through tables
    for k in kv_list:
        # get table title
        # some tables won't have a title, which we ignore
        try:
            title = k.find(class_='ps-kv-list-title').text.lower().replace(' ', '-')
        except AttributeError as a_err:
            print('Error on table for: {}'.format(url))
            continue
        # instantiate dict for each title
        scrapped_dict[url_key]['tables'][title] = {}
        # get table content
        contents = k.findAll('div', class_='grid-x')
        # iterate through table content
        for content in contents:
            entry = content.text.strip().split('\n')
            scrapped_dict[url_key]['tables'][title][entry[0]] = entry[1]
# Out:
# Error on table for: https://propsearch.ae/dubai/mama-shelter-dubai
# Error on table for: https://propsearch.ae/dubai/amna-tower
# Error on table for: https://propsearch.ae/dubai/dorchester-hotel-dubai
# Error on table for: https://propsearch.ae/dubai/zada-tower

# %%
scrapped_dict
# Out:
# {'96': {'url': 'https://propsearch.ae/dubai/millennium-binghatti-residences',
#   'tables': {'millennium-binghatti-residences-key-information': {'Location type': 'Residential building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '24',
#     'Building type': 'High-rise building',
#     'Total units': '230',
#     'Unit types': '113 studios58 one-bedroom apartments59 two-bedroom apartments'},
#    'companies-associated-with-millennium-binghatti-residences': {'Developer': 'Binghatti Developers',
#     'Architectural Consultant': 'Eng. Adnan Saffarini',
#     'Contractor': 'Granada Europe Engineering Contracting Co.'},
#    'millennium-binghatti-residences-milestones': {'Date Launched': 'March 2018',
#     'Estimated Handover Date': 'Q4 2019',
#     'Construction Started': '2018'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '20 mins drive',
#     'Al Maktoum International Airport': '42 mins drive',
#     'La Mer by Meraas': '19 mins drive',
#     'Mall of the Emirates': '16 mins drive',
#     'Dubai Mall': '10 mins drive',
#     'Burj Al Arab': '19 mins drive',
#     'Ibn Battuta Mall': '24 mins drive',
#     'The Walk JBR': '24 mins drive',
#     'Dubai International Airport': '20 mins drive'}},
#   'coordinates': '25°10 51"N 55°16 8.8"E',
#   'last_photo_update': {'caption': 'Millennium Binghatti Residences, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/millennium-binghatti-residences-28556_xl.jpg'}},
#  '98': {'url': 'https://propsearch.ae/dubai/moon-tower',
#   'tables': {'moon-tower-key-information': {'Location type': 'Residential building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '20',
#     'Building type': 'High-rise building',
#     'Total units': '255',
#     'Unit types': 'StudiosOne-bedroom apartmentsTwo-bedroom apartments'},
#    'companies-associated-with-moon-tower': {'Developer': 'Arabia Group Investment Limited',
#     'Architectural Consultant': 'Chawla Architectural & Consulting Engineers'},
#    'moon-tower-milestones': {'Date Launched': '2007',
#     'Revised Estimated Handover Date': 'Q4 2016',
#     'Construction Started': '2009'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '21 mins drive',
#     'Al Maktoum International Airport': '42 mins drive',
#     'La Mer by Meraas': '20 mins drive',
#     'Mall of the Emirates': '16 mins drive',
#     'Dubai Mall': '13 mins drive',
#     'Burj Al Arab': '20 mins drive',
#     'Ibn Battuta Mall': '25 mins drive',
#     'The Walk JBR': '25 mins drive',
#     'Dubai International Airport': '20 mins drive'}},
#   'coordinates': '25°11 3.5"N 55°17 5.1"E',
#   'last_photo_update': {'caption': 'Moon Tower, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/moon-tower-28532_xl.jpg'}},
#  '99': {'url': 'https://propsearch.ae/dubai/movenpick-hotel-living',
#   'tables': {'mövenpick-hotel-&-living-key-information': {'Location type': 'Residential building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '36',
#     'Building type': 'Skyscraper',
#     'Total units': '403'},
#    'companies-associated-with-mövenpick-hotel-&-living': {'Developer': 'SAAS Properties',
#     'Architectural Consultant': 'National Engineering Bureau',
#     'Contractor': 'Kele Contracting'},
#    'mövenpick-hotel-&-living-milestones': {'Estimated Handover Date': 'Q4 2016',
#     'Construction Started': '2015'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '21 mins drive',
#     'Al Maktoum International Airport': '44 mins drive',
#     'La Mer by Meraas': '17 mins drive',
#     'Mall of the Emirates': '16 mins drive',
#     'Dubai Mall': '7 mins drive',
#     'Burj Al Arab': '19 mins drive',
#     'Ibn Battuta Mall': '25 mins drive',
#     'The Walk JBR': '24 mins drive',
#     'Dubai International Airport': '17 mins drive'}},
#   'coordinates': '25°11 19.6"N 55°16 13.1"E',
#   'last_photo_update': {'caption': 'Mövenpick Hotel Apartments Business Bay, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/movenpick-hotel-apartments-business-bay-28626_xl.jpg'}},
#  '108': {'url': 'https://propsearch.ae/dubai/nobles-residential-tower',
#   'tables': {'nobles-residential-tower-key-information': {'Location type': 'Residential building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '53',
#     'Floors below ground': '2',
#     'Building type': 'Skyscraper',
#     'Total units': '549',
#     'Unit types': '278 one-bedroom apartments239 two-bedroom apartments32 three-bedroom apartments'},
#    'companies-associated-with-nobles-residential-tower': {'Developer': 'Tiger Properties',
#     'Architectural Consultant': 'LACASA Architects & Engineering Consultants',
#     'Contractor': 'Tiger International General Contracting'},
#    'nobles-residential-tower-milestones': {'Date Launched': 'September 2017',
#     'Construction Started': '2019'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '22 mins drive',
#     'Al Maktoum International Airport': '43 mins drive',
#     'La Mer by Meraas': '18 mins drive',
#     'Mall of the Emirates': '18 mins drive',
#     'Dubai Mall': '10 mins drive',
#     'Burj Al Arab': '21 mins drive',
#     'Ibn Battuta Mall': '26 mins drive',
#     'The Walk JBR': '26 mins drive',
#     'Dubai International Airport': '16 mins drive'}},
#   'coordinates': '25°11 4.5"N 55°17 24.8"E',
#   'last_photo_update': {'caption': 'Nobles Residential Tower, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/nobles-residential-tower-28522_xl.jpg'}},
#  '110': {'url': 'https://propsearch.ae/dubai/marble-arch-tower',
#   'tables': {'marble-arch-tower-key-information': {'Location type': 'Residential building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development'},
#    'companies-associated-with-marble-arch-tower': {'Architectural Consultant': 'DXB Design Studio',
#     'Contractor': 'Modern Executive Systems Contracting',
#     'Piling Contractor': 'Geo Foundation Group'},
#    'marble-arch-tower-milestones': {'Construction Started': '2019'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '19 mins drive',
#     'Al Maktoum International Airport': '42 mins drive',
#     'La Mer by Meraas': '17 mins drive',
#     'Mall of the Emirates': '14 mins drive',
#     'Dubai Mall': '11 mins drive',
#     'Burj Al Arab': '17 mins drive',
#     'Ibn Battuta Mall': '22 mins drive',
#     'The Walk JBR': '22 mins drive',
#     'Dubai International Airport': '19 mins drive'}},
#   'coordinates': '25°10 46.8"N 55°15 53.9"E',
#   'last_photo_update': {'caption': 'Marble Arch Tower, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/marble-arch-tower-28563_xl.jpg'}},
#  '118': {'url': 'https://propsearch.ae/dubai/mama-shelter-dubai',
#   'tables': {'mama-shelter-dubai-key-information': {'Location type': 'Mixed-use building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '25',
#     'Floors below ground': '3',
#     'Building type': 'Skyscraper',
#     'Total units': '201'},
#    'companies-associated-with-mama-shelter-dubai': {'Developer': 'Kappa Acca Real Estate Development',
#     'Owner': 'Khamas Group of Investment Companies',
#     'Architectural Consultant': 'Franklin Azzi Architecture',
#     'Contractor': 'CRC Engineering Company LLC',
#     'Piling Contractor': 'TMF Euro Foundations'},
#    'mama-shelter-dubai-milestones': {'Date Launched': 'May 2017',
#     'Estimated Handover Date': '2020',
#     'Construction Started': '2018'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '21 mins drive',
#     'Al Maktoum International Airport': '42 mins drive',
#     'La Mer by Meraas': '20 mins drive',
#     'Mall of the Emirates': '16 mins drive',
#     'Dubai Mall': '11 mins drive',
#     'Burj Al Arab': '20 mins drive',
#     'Ibn Battuta Mall': '25 mins drive',
#     'The Walk JBR': '24 mins drive',
#     'Dubai International Airport': '21 mins drive'}},
#   'coordinates': '25°10 48.3"N 55°16 18.9"E',
#   'last_photo_update': {'caption': 'Mama Shelter Dubai, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/mama-shelter-dubai-28548_xl.jpg'}},
#  '121': {'url': 'https://propsearch.ae/dubai/lillian-tower',
#   'tables': {'lillian-tower-key-information': {'Location type': 'Mixed-use building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '30',
#     'Floors below ground': '3',
#     'Building type': 'Skyscraper',
#     'Total units': '583'},
#    'companies-associated-with-lillian-tower': {'Developer': 'Marya Investments'},
#    'lillian-tower-milestones': {'Date Launched': '2007',
#     'Estimated Handover Date': '2016'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '18 mins drive',
#     'Al Maktoum International Airport': '42 mins drive',
#     'La Mer by Meraas': '17 mins drive',
#     'Mall of the Emirates': '13 mins drive',
#     'Dubai Mall': '7 mins drive',
#     'Burj Al Arab': '16 mins drive',
#     'Ibn Battuta Mall': '22 mins drive',
#     'The Walk JBR': '21 mins drive',
#     'Dubai International Airport': '18 mins drive'}},
#   'coordinates': '25°11 14.3"N 55°15 45.4"E',
#   'last_photo_update': {'caption': 'Lillian Tower, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/lillian-tower-28578_xl.jpg'}},
#  '133': {'url': 'https://propsearch.ae/dubai/ag-tower-business-bay',
#   'tables': {'ag-tower-business-bay-key-information': {'Location type': 'Residential building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '29',
#     'Building type': 'Skyscraper',
#     'Total units': '437',
#     'Unit types': 'One-bedroom apartmentsTwo-bedroom apartmentsThree-bedroom apartments'},
#    'companies-associated-with-ag-tower-business-bay': {'Developer': 'Arabian Gulf Properties',
#     'Financier': 'Emirates NBD',
#     'Architectural Consultant': 'CVTEC Consulting Engineers',
#     'Contractor': 'Beijing Emirates International Construction Co.',
#     'MEP Consultant': 'City Compass Electromechanical'},
#    'ag-tower-business-bay-milestones': {'Date Launched': '2015',
#     'Construction Started': '2016'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '18 mins drive',
#     'Al Maktoum International Airport': '38 mins drive',
#     'La Mer by Meraas': '17 mins drive',
#     'Mall of the Emirates': '14 mins drive',
#     'Dubai Mall': '10 mins drive',
#     'Burj Al Arab': '17 mins drive',
#     'Ibn Battuta Mall': '22 mins drive',
#     'The Walk JBR': '22 mins drive',
#     'Dubai International Airport': '18 mins drive'}},
#   'coordinates': '25°10 47.6"N 55°16 8.9"E',
#   'last_photo_update': {'caption': 'AG Tower Business Bay, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/ag-tower-business-bay-28560_xl.jpg'}},
#  '134': {'url': 'https://propsearch.ae/dubai/ahad-residences',
#   'tables': {'ahad-residences-key-information': {'Location type': 'Residential building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '31',
#     'Floors below ground': '5',
#     'Building type': 'Skyscraper'},
#    'companies-associated-with-ahad-residences': {'Developer': 'Mercury Investment Holding',
#     'Architectural Consultant': 'VX Architects',
#     'Interior Designer': 'Opaal',
#     'Contractor': 'Evan Lim Penta Construction LLC'},
#    'ahad-residences-milestones': {'Date Launched': '2017',
#     'Construction Started': '2018'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '22 mins drive',
#     'Al Maktoum International Airport': '46 mins drive',
#     'La Mer by Meraas': '19 mins drive',
#     'Mall of the Emirates': '18 mins drive',
#     'Dubai Mall': '8 mins drive',
#     'Burj Al Arab': '21 mins drive',
#     'Ibn Battuta Mall': '26 mins drive',
#     'The Walk JBR': '26 mins drive',
#     'Dubai International Airport': '19 mins drive'}},
#   'coordinates': '25°11 12"N 55°15 57.6"E',
#   'last_photo_update': {'caption': 'Ahad Residences, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/ahad-residences-28628_xl.jpg'}},
#  '140': {'url': 'https://propsearch.ae/dubai/paramount-tower-hotel-residences',
#   'tables': {'paramount-tower-hotel-&-residences-key-information': {'Location type': 'Mixed-use building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '66',
#     'Building type': 'Skyscraper',
#     'Total units': '826'},
#    'companies-associated-with-paramount-tower-hotel-&-residences': {'Developer': 'Damac Properties',
#     'Architectural Consultant': 'LACASA Architects & Engineering Consultants'},
#    'paramount-tower-hotel-&-residences-milestones': {'Date Launched': 'September 2014',
#     'Estimated Handover Date': 'Q3 2019',
#     'Construction Started': '2015'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '21 mins drive',
#     'Al Maktoum International Airport': '46 mins drive',
#     'La Mer by Meraas': '15 mins drive',
#     'Mall of the Emirates': '16 mins drive',
#     'Dubai Mall': '7 mins drive',
#     'Burj Al Arab': '19 mins drive',
#     'Ibn Battuta Mall': '25 mins drive',
#     'The Walk JBR': '24 mins drive',
#     'Dubai International Airport': '15 mins drive'}},
#   'coordinates': '25°11 36.3"N 55°15 55.3"E',
#   'last_photo_update': {'caption': 'Paramount Tower Hotel &amp; Residences, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/paramount-tower-hotel-residences-28638_xl.jpg'}},
#  '144': {'url': 'https://propsearch.ae/dubai/amna-tower',
#   'tables': {'amna-tower-key-information': {'Location type': 'Residential building',
#     'Area': 'Al Habtoor City',
#     'Phase': 'Under development',
#     'Floors': '52',
#     'Height': '307 metres (1,007 feet)',
#     'Building type': 'Skyscraper',
#     'Total units': '537',
#     'Unit types': 'One-bedroom apartmentsTwo-bedroom apartmentsThree-bedroom apartmentsFour-bedroom apartmentsFive-bedroom apartmentsSix-bedroom apartmentsPenthouses'},
#    'companies-associated-with-amna-tower': {'Developer': 'Al Habtoor Group',
#     'Architectural Consultant': 'WS Atkins & Partners'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '18 mins drive',
#     'Al Maktoum International Airport': '40 mins drive',
#     'La Mer by Meraas': '14 mins drive',
#     'Mall of the Emirates': '13 mins drive',
#     'Dubai Mall': '10 mins drive',
#     'Burj Al Arab': '16 mins drive',
#     'Ibn Battuta Mall': '21 mins drive',
#     'The Walk JBR': '21 mins drive',
#     'Dubai International Airport': '18 mins drive'}},
#   'coordinates': '25°10 57.2"N 55°15 20.6"E',
#   'last_photo_update': {'caption': 'Amna Tower, construction update July 2020.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/amna-tower-22350_xl.jpg'}},
#  '158': {'url': 'https://propsearch.ae/dubai/kingston-towers-business-bay',
#   'tables': {'kingston-towers-business-bay-key-information': {'Location type': 'Multi-building complex',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors below ground': '2'},
#    'companies-associated-with-kingston-towers-business-bay': {'Developer': 'Kingston',
#     'Project Manager': 'Faithful & Gould',
#     'Architectural Consultant': 'Canadian Consultant',
#     'Engineering Consultant': 'MAK Consultancy & Architects',
#     'Contractor': 'Gulf Asia Contracting',
#     'Piling Contractor': 'Delta Foundations Co.'},
#    'kingston-towers-business-bay-milestones': {'Date Launched': '2018',
#     'Construction Started': '2019'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '18 mins drive',
#     'Al Maktoum International Airport': '39 mins drive',
#     'La Mer by Meraas': '17 mins drive',
#     'Mall of the Emirates': '14 mins drive',
#     'Dubai Mall': '9 mins drive',
#     'Burj Al Arab': '17 mins drive',
#     'Ibn Battuta Mall': '21 mins drive',
#     'The Walk JBR': '22 mins drive',
#     'Dubai International Airport': '16 mins drive'}},
#   'coordinates': '25°10 49.8"N 55°16 42.1"E',
#   'last_photo_update': {'caption': 'Kingston Towers Business Bay, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/kingston-towers-business-bay-28538_xl.jpg'}},
#  '167': {'url': 'https://propsearch.ae/dubai/sky-bay-hotel',
#   'tables': {'sky-bay-hotel-key-information': {'Location type': 'Hotel',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '18',
#     'Building type': 'High-rise building',
#     'Total units': '440',
#     'Unit types': '440 hotel rooms'},
#    'companies-associated-with-sky-bay-hotel': {'Developer': 'The First Group',
#     'Architectural Consultant': 'Alajmi Engineering Consultants',
#     'Contractor': 'Al Habbai Contracting LLC'},
#    'sky-bay-hotel-milestones': {'Construction Started': '2016'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '18 mins drive',
#     'Al Maktoum International Airport': '40 mins drive',
#     'La Mer by Meraas': '17 mins drive',
#     'Mall of the Emirates': '14 mins drive',
#     'Dubai Mall': '10 mins drive',
#     'Burj Al Arab': '17 mins drive',
#     'Ibn Battuta Mall': '21 mins drive',
#     'The Walk JBR': '22 mins drive',
#     'Dubai International Airport': '18 mins drive'}},
#   'coordinates': '25°10 41.3"N 55°16 4.7"E',
#   'last_photo_update': {'caption': 'Sky Bay Hotel, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/sky-bay-hotel-28565_xl.jpg'}},
#  '173': {'url': 'https://propsearch.ae/dubai/safeer-tower-3',
#   'tables': {'safeer-tower-3-key-information': {'Location type': 'Residential building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '20',
#     'Floors below ground': '1',
#     'Building type': 'High-rise building'},
#    'companies-associated-with-safeer-tower-3': {'Developer': 'Al Seeb Real Estate Development',
#     'Architectural Consultant': 'National Engineering Bureau',
#     'Contractor': 'Rose City Contracting LLC'},
#    'safeer-tower-3-milestones': {'Date Launched': '2018',
#     'Construction Started': '2019'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '19 mins drive',
#     'Al Maktoum International Airport': '39 mins drive',
#     'La Mer by Meraas': '17 mins drive',
#     'Mall of the Emirates': '14 mins drive',
#     'Dubai Mall': '10 mins drive',
#     'Burj Al Arab': '17 mins drive',
#     'Ibn Battuta Mall': '22 mins drive',
#     'The Walk JBR': '22 mins drive',
#     'Dubai International Airport': '16 mins drive'}},
#   'coordinates': '25°10 47.6"N 55°16 40.4"E',
#   'last_photo_update': {'caption': 'Safeer Tower 3, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/safeer-tower-3-28541_xl.jpg'}},
#  '177': {'url': 'https://propsearch.ae/dubai/ritz-carlton-hotel-apartments',
#   'tables': {'ritz-carlton-hotel-apartments-key-information': {'Location type': 'Hotel apartments building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development'},
#    'companies-associated-with-ritz-carlton-hotel-apartments': {'Developer': 'Kappa Acca Real Estate Development',
#     'Owner': 'Khamas Group of Investment Companies',
#     'Architectural Consultant': 'National Engineering Bureau',
#     'Contractor': 'AIC Contracting'},
#    'ritz-carlton-hotel-apartments-milestones': {'Date Launched': 'Q1 2021'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '20 mins drive',
#     'Al Maktoum International Airport': '38 mins drive',
#     'La Mer by Meraas': '20 mins drive',
#     'Mall of the Emirates': '15 mins drive',
#     'Dubai Mall': '12 mins drive',
#     'Burj Al Arab': '18 mins drive',
#     'Ibn Battuta Mall': '23 mins drive',
#     'The Walk JBR': '24 mins drive',
#     'Dubai International Airport': '20 mins drive'}},
#   'coordinates': '25°11 4.7"N 55°17 6.4"E',
#   'last_photo_update': {'caption': 'Ritz Carlton Hotel Apartments, construction site signboard.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/ritz-carlton-hotel-apartments-28528_xl.jpg'}},
#  '178': {'url': 'https://propsearch.ae/dubai/reva-by-damac',
#   'tables': {'reva-by-damac-key-information': {'Location type': 'Multi-building complex',
#     'Area': 'Business Bay',
#     'Phase': 'Under development'},
#    'companies-associated-with-reva-by-damac': {'Developer': 'Damac Properties',
#     'Architectural Consultant': 'U+A Architects',
#     'Contractor': 'Arabtec Construction',
#     'Piling Contractor': 'National Piling Company'},
#    'reva-by-damac-milestones': {'Date Launched': 'January 2018',
#     'Construction Started': '2018'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '22 mins drive',
#     'Al Maktoum International Airport': '44 mins drive',
#     'La Mer by Meraas': '19 mins drive',
#     'Mall of the Emirates': '18 mins drive',
#     'Dubai Mall': '9 mins drive',
#     'Burj Al Arab': '21 mins drive',
#     'Ibn Battuta Mall': '26 mins drive',
#     'The Walk JBR': '26 mins drive',
#     'Dubai International Airport': '16 mins drive'}},
#   'coordinates': '25°11 16"N 55°16 59.1"E',
#   'last_photo_update': {'caption': 'Reva by Damac, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/reva-by-damac-28605_xl.jpg'}},
#  '185': {'url': 'https://propsearch.ae/dubai/ramee-grand-hotel-spa',
#   'tables': {'ramee-grand-hotel-&-spa-key-information': {'Location type': 'Hotel',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '20',
#     'Floors below ground': '4',
#     'Building type': 'High-rise building'},
#    'companies-associated-with-ramee-grand-hotel-&-spa': {'Developer': 'Ramee Group',
#     'Architectural Consultant': 'Archgroup Consultants',
#     'Contractor': 'Delta Al Wadi Contracting',
#     'Piling Contractor': 'Delta Foundations Co.'},
#    'ramee-grand-hotel-&-spa-milestones': {'Date Launched': '2017',
#     'Construction Started': '2018'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '20 mins drive',
#     'Al Maktoum International Airport': '42 mins drive',
#     'La Mer by Meraas': '17 mins drive',
#     'Mall of the Emirates': '15 mins drive',
#     'Dubai Mall': '8 mins drive',
#     'Burj Al Arab': '19 mins drive',
#     'Ibn Battuta Mall': '24 mins drive',
#     'The Walk JBR': '23 mins drive',
#     'Dubai International Airport': '14 mins drive'}},
#   'coordinates': '25°11 17.2"N 55°16 53.6"E',
#   'last_photo_update': {'caption': 'Ramee Grand Hotel &amp; Spa, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/ramee-grand-hotel-spa-28593_xl.jpg'}},
#  '189': {'url': 'https://propsearch.ae/dubai/srg-holding-hotel-business-bay',
#   'tables': {'srg-holding-hotel-business-bay-key-information': {'Location type': 'Mixed-use building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '29',
#     'Floors below ground': '1',
#     'Building type': 'Skyscraper'},
#    'companies-associated-with-srg-holding-hotel-business-bay': {'Developer': 'SRG Holding Limited',
#     'Architectural Consultant': 'ERGA Progress Engineering Consultants',
#     'Contractor': 'Al Habbai Contracting LLC'},
#    'srg-holding-hotel-business-bay-milestones': {'Date Launched': '2018',
#     'Construction Started': '2018'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '23 mins drive',
#     'Al Maktoum International Airport': '43 mins drive',
#     'La Mer by Meraas': '19 mins drive',
#     'Mall of the Emirates': '18 mins drive',
#     'Dubai Mall': '10 mins drive',
#     'Burj Al Arab': '21 mins drive',
#     'Ibn Battuta Mall': '26 mins drive',
#     'The Walk JBR': '26 mins drive',
#     'Dubai International Airport': '17 mins drive'}},
#   'coordinates': '25°11 6"N 55°17 23.1"E',
#   'last_photo_update': {'caption': 'SRG Holding Hotel Business Bay, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/srg-holding-hotel-business-bay-28521_xl.jpg'}},
#  '192': {'url': 'https://propsearch.ae/dubai/kempinski-business-bay',
#   'tables': {'kempinski-business-bay-key-information': {'Location type': 'Hotel',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '25',
#     'Building type': 'Skyscraper',
#     'Total units': '240',
#     'Unit types': '240 hotel rooms'},
#    'companies-associated-with-kempinski-business-bay': {'Developer': 'Seastar Properties Limited',
#     'Architectural Consultant': 'National Engineering Bureau'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '20 mins drive',
#     'Al Maktoum International Airport': '40 mins drive',
#     'La Mer by Meraas': '18 mins drive',
#     'Mall of the Emirates': '15 mins drive',
#     'Dubai Mall': '12 mins drive',
#     'Burj Al Arab': '18 mins drive',
#     'Ibn Battuta Mall': '24 mins drive',
#     'The Walk JBR': '23 mins drive',
#     'Dubai International Airport': '20 mins drive'}},
#   'coordinates': '25°10 54.3"N 55°16 45.1"E',
#   'last_photo_update': {'caption': 'Kempinski Business Bay, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/kempinski-business-bay-28611_xl.jpg'}},
#  '193': {'url': 'https://propsearch.ae/dubai/kasco-tower',
#   'tables': {'kasco-tower-key-information': {'Location type': 'Residential building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '23',
#     'Floors below ground': '2',
#     'Building type': 'High-rise building'},
#    'companies-associated-with-kasco-tower': {'Developer': 'Ahmed Al Janabi',
#     'Architectural Consultant': 'Next Engineering Consultants',
#     'Contractor': 'Sumer Contracting Company'},
#    'kasco-tower-milestones': {'Date Launched': '2018',
#     'Construction Started': '2018'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '21 mins drive',
#     'Al Maktoum International Airport': '42 mins drive',
#     'La Mer by Meraas': '19 mins drive',
#     'Mall of the Emirates': '16 mins drive',
#     'Dubai Mall': '12 mins drive',
#     'Burj Al Arab': '19 mins drive',
#     'Ibn Battuta Mall': '25 mins drive',
#     'The Walk JBR': '24 mins drive',
#     'Dubai International Airport': '21 mins drive'}},
#   'coordinates': '25°11 0.9"N 55°17 2.5"E',
#   'last_photo_update': {'caption': 'Kasco Tower, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/kasco-tower-28531_xl.jpg'}},
#  '196': {'url': 'https://propsearch.ae/dubai/j-one',
#   'tables': {'j-one-key-information': {'Location type': 'Multi-building complex',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Total units': '347'},
#    'companies-associated-with-j-one': {'Developer': 'RKM Real Estate LLC',
#     'Financier': 'Commercial Bank of Dubai',
#     'Architectural Consultant': 'QHC Architects & Engineers LLC',
#     'Contractor': 'Ali & Sons Contracting'},
#    'j-one-milestones': {'Date Launched': 'August 2017',
#     'Construction Started': '2017'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '20 mins drive',
#     'Al Maktoum International Airport': '42 mins drive',
#     'La Mer by Meraas': '18 mins drive',
#     'Mall of the Emirates': '15 mins drive',
#     'Dubai Mall': '8 mins drive',
#     'Burj Al Arab': '19 mins drive',
#     'Ibn Battuta Mall': '24 mins drive',
#     'The Walk JBR': '24 mins drive',
#     'Dubai International Airport': '15 mins drive'}},
#   'coordinates': '25°11 10.3"N 55°17 0"E',
#   'last_photo_update': {'caption': 'J One, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/j-one-28607_xl.jpg'}},
#  '209': {'url': 'https://propsearch.ae/dubai/the-court-tower',
#   'tables': {'the-court-tower-key-information': {'Location type': 'Office building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '30',
#     'Building type': 'Skyscraper'},
#    'companies-associated-with-the-court-tower': {'Developer': 'Tanmiyat Global',
#     'Architectural Consultant': 'Al Hazmi & Associates Consultant'},
#    'the-court-tower-milestones': {'Date Launched': '2005',
#     'Construction Started': '2006'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '20 mins drive',
#     'Al Maktoum International Airport': '43 mins drive',
#     'La Mer by Meraas': '15 mins drive',
#     'Mall of the Emirates': '16 mins drive',
#     'Dubai Mall': '7 mins drive',
#     'Burj Al Arab': '19 mins drive',
#     'Ibn Battuta Mall': '24 mins drive',
#     'The Walk JBR': '24 mins drive',
#     'Dubai International Airport': '16 mins drive'}},
#   'coordinates': '25°11 4.8"N 55°15 31.8"E',
#   'last_photo_update': {'caption': 'The Court Tower, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/the-court-tower-28572_xl.jpg'}},
#  '219': {'url': 'https://propsearch.ae/dubai/the-one-hotel-business-bay',
#   'tables': {'the-one-hotel-business-bay-key-information': {'Location type': 'Hotel',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '18',
#     'Floors below ground': '2',
#     'Building type': 'High-rise building',
#     'Total units': '492',
#     'Unit types': '492 hotel rooms'},
#    'companies-associated-with-the-one-hotel-business-bay': {'Developer': 'The First Group',
#     'Architectural Consultant': 'Engineering Consultants Group',
#     'Contractor': 'China Railway 18th Bureau Group',
#     'Piling Contractor': 'Stromek Emirates Foundations',
#     'MEP Consultant': 'Heat & Power Turnkey MEP Solutions'},
#    'the-one-hotel-business-bay-milestones': {'Date Launched': 'July 2016',
#     'Construction Started': '2017'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '19 mins drive',
#     'Al Maktoum International Airport': '39 mins drive',
#     'La Mer by Meraas': '17 mins drive',
#     'Mall of the Emirates': '14 mins drive',
#     'Dubai Mall': '10 mins drive',
#     'Burj Al Arab': '17 mins drive',
#     'Ibn Battuta Mall': '23 mins drive',
#     'The Walk JBR': '22 mins drive',
#     'Dubai International Airport': '17 mins drive'}},
#   'coordinates': '25°10 44.3"N 55°16 32.8"E',
#   'last_photo_update': {'caption': 'The One Hotel Business Bay, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/the-one-hotel-business-bay-28543_xl.jpg'}},
#  '233': {'url': 'https://propsearch.ae/dubai/dorchester-hotel-dubai',
#   'tables': {'dorchester-hotel-dubai-key-information': {'Location type': 'Hotel',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '32',
#     'Floors below ground': '2',
#     'Building type': 'Skyscraper'},
#    'companies-associated-with-dorchester-hotel-dubai': {'Developer': 'Sky Palaces Real Estate',
#     'Financier': 'Ajman Bank',
#     'Architectural Consultant': 'Foster + Partners',
#     'Contractor': 'Roberts Constructions',
#     'Piling Contractor': 'NSCC International'},
#    'dorchester-hotel-dubai-milestones': {'Date Launched': '2017',
#     'Estimated Handover Date': '2020',
#     'Construction Started': '2017'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '22 mins drive',
#     'Al Maktoum International Airport': '42 mins drive',
#     'La Mer by Meraas': '20 mins drive',
#     'Mall of the Emirates': '17 mins drive',
#     'Dubai Mall': '13 mins drive',
#     'Burj Al Arab': '20 mins drive',
#     'Ibn Battuta Mall': '26 mins drive',
#     'The Walk JBR': '25 mins drive',
#     'Dubai International Airport': '22 mins drive'}},
#   'coordinates': '25°11 16.3"N 55°17 17.6"E',
#   'last_photo_update': {'caption': 'Dorchester Hotel Dubai, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/dorchester-hotel-dubai-28550_xl.jpg'}},
#  '243': {'url': 'https://propsearch.ae/dubai/dolphin-tower',
#   'tables': {'dolphin-tower-key-information': {'Location type': 'Hotel apartments building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '22',
#     'Building type': 'High-rise building',
#     'Total units': '330',
#     'Unit types': '330 hotel rooms'},
#    'companies-associated-with-dolphin-tower': {'Owner': 'Farida Farnood',
#     'Hotel Operator': 'The First Group',
#     'Architectural Consultant': 'Arab Experts Engineering Consultants',
#     'Contractor': 'Modern Executive Systems Contracting'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '20 mins drive',
#     'Al Maktoum International Airport': '40 mins drive',
#     'La Mer by Meraas': '19 mins drive',
#     'Mall of the Emirates': '16 mins drive',
#     'Dubai Mall': '12 mins drive',
#     'Burj Al Arab': '19 mins drive',
#     'Ibn Battuta Mall': '24 mins drive',
#     'The Walk JBR': '24 mins drive',
#     'Dubai International Airport': '20 mins drive'}},
#   'coordinates': '25°10 59.1"N 55°16 59.4"E',
#   'last_photo_update': {'caption': 'Dolphin Tower, construction update January 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/dolphin-tower-26490_xl.jpg'}},
#  '285': {'url': 'https://propsearch.ae/dubai/bayz-by-danube',
#   'tables': {'bayz-by-danube-key-information': {'Location type': 'Residential building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '30',
#     'Building type': 'Skyscraper',
#     'Total units': '456',
#     'Unit types': '264 studios120 one-bedroom apartments48 two-bedroom apartments24 three-bedroom apartments'},
#    'companies-associated-with-bayz-by-danube': {'Developer': 'Danube Properties Development LLC',
#     'Architectural Consultant': 'National Engineering Bureau',
#     'Contractor': 'RAQ Contracting Co LLC'},
#    'bayz-by-danube-milestones': {'Date Launched': 'May 2017',
#     'Construction Started': '2018'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '18 mins drive',
#     'Al Maktoum International Airport': '38 mins drive',
#     'La Mer by Meraas': '17 mins drive',
#     'Mall of the Emirates': '14 mins drive',
#     'Dubai Mall': '9 mins drive',
#     'Burj Al Arab': '17 mins drive',
#     'Ibn Battuta Mall': '22 mins drive',
#     'The Walk JBR': '22 mins drive',
#     'Dubai International Airport': '16 mins drive'}},
#   'coordinates': '25°10 50.5"N 55°16 45.5"E',
#   'last_photo_update': {'caption': 'Bayz by Danube, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/bayz-by-danube-28539_xl.jpg'}},
#  '291': {'url': 'https://propsearch.ae/dubai/corporate-bay-tower',
#   'tables': {'corporate-bay-tower-key-information': {'Location type': 'Office building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '30',
#     'Floors below ground': '5',
#     'Building type': 'Skyscraper'},
#    'companies-associated-with-corporate-bay-tower': {'Developer': 'Goldline Real Estate Development LLC',
#     'Architectural Consultant': 'Em Square Engineering Consultants',
#     'Contractor': 'China State Construction Engineering Corporation'},
#    'corporate-bay-tower-milestones': {'Construction Started': '2007'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '20 mins drive',
#     'Al Maktoum International Airport': '44 mins drive',
#     'La Mer by Meraas': '19 mins drive',
#     'Mall of the Emirates': '15 mins drive',
#     'Dubai Mall': '10 mins drive',
#     'Burj Al Arab': '19 mins drive',
#     'Ibn Battuta Mall': '24 mins drive',
#     'The Walk JBR': '24 mins drive',
#     'Dubai International Airport': '19 mins drive'}},
#   'coordinates': '25°11 5.3"N 55°15 40.1"E',
#   'last_photo_update': {'caption': 'Corporate Bay Tower, construction update January 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/corporate-bay-tower-26537_xl.jpg'}},
#  '295': {'url': 'https://propsearch.ae/dubai/tiara-united-towers',
#   'tables': {'tiara-united-towers-key-information': {'Location type': 'Multi-building complex',
#     'Area': 'Business Bay',
#     'Phase': 'Under development'},
#    'companies-associated-with-tiara-united-towers': {'Developer': 'Zabeel Investments'},
#    'tiara-united-towers-milestones': {'Construction Started': '2006'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '17 mins drive',
#     'Al Maktoum International Airport': '42 mins drive',
#     'La Mer by Meraas': '15 mins drive',
#     'Mall of the Emirates': '12 mins drive',
#     'Dubai Mall': '10 mins drive',
#     'Burj Al Arab': '15 mins drive',
#     'Ibn Battuta Mall': '21 mins drive',
#     'The Walk JBR': '20 mins drive',
#     'Dubai International Airport': '18 mins drive'}},
#   'coordinates': '25°11 19.8"N 55°15 35.7"E',
#   'last_photo_update': {'caption': 'Tiara United Towers, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/tiara-united-towers-28577_xl.jpg'}},
#  '296': {'url': 'https://propsearch.ae/dubai/commercial-residential-tower-plot-3460763',
#   'tables': {'commercial-&-residential-tower-plot-3460763-key-information': {'Location type': 'Residential building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '21',
#     'Floors below ground': '2',
#     'Building type': 'High-rise building'},
#    'companies-associated-with-commercial-&-residential-tower-plot-3460763': {'Architectural Consultant': 'Art Consultants Dubai',
#     'Contractor': 'Gulf Asia Contracting',
#     'Piling Contractor': 'Edrafor Piling And Special Foundation'},
#    'commercial-&-residential-tower-plot-3460763-milestones': {'Construction Started': '2019'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '21 mins drive',
#     'Al Maktoum International Airport': '41 mins drive',
#     'La Mer by Meraas': '17 mins drive',
#     'Mall of the Emirates': '16 mins drive',
#     'Dubai Mall': '8 mins drive',
#     'Burj Al Arab': '19 mins drive',
#     'Ibn Battuta Mall': '24 mins drive',
#     'The Walk JBR': '24 mins drive',
#     'Dubai International Airport': '14 mins drive'}},
#   'coordinates': '25°11 25.9"N 55°17 27.7"E',
#   'last_photo_update': {'caption': 'Commercial &amp; Residential Tower Plot 3460763, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/commercial-residential-tower-plot-3460763-28516_xl.jpg'}},
#  '298': {'url': 'https://propsearch.ae/dubai/zada-tower',
#   'tables': {'zada-tower-key-information': {'Location type': 'Residential building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '30',
#     'Floors below ground': '4',
#     'Building type': 'Skyscraper',
#     'Total units': '699',
#     'Unit types': '699 one-bedroom apartments'},
#    'companies-associated-with-zada-tower': {'Developer': 'Damac Properties',
#     'Architectural Consultant': 'Kieferle & Partner',
#     'Contractor': 'Transemirates Contracting',
#     'Piling Contractor': 'National Piling Company'},
#    'zada-tower-milestones': {'Date Launched': 'April 2019'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '20 mins drive',
#     'Al Maktoum International Airport': '44 mins drive',
#     'La Mer by Meraas': '19 mins drive',
#     'Mall of the Emirates': '16 mins drive',
#     'Dubai Mall': '10 mins drive',
#     'Burj Al Arab': '19 mins drive',
#     'Ibn Battuta Mall': '24 mins drive',
#     'The Walk JBR': '24 mins drive',
#     'Dubai International Airport': '19 mins drive'}},
#   'coordinates': '25°11 4.6"N 55°15 42"E',
#   'last_photo_update': {'caption': 'Zada Tower, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/zada-tower-28566_xl.jpg'}},
#  '299': {'url': 'https://propsearch.ae/dubai/yotel-dubai',
#   'tables': {'yotel-dubai-key-information': {'Location type': 'Hotel',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '42',
#     'Building type': 'Skyscraper',
#     'Total units': '565',
#     'Unit types': '565 hotel rooms'},
#    'companies-associated-with-yotel-dubai': {'Developer': 'Dubai Investment Properties'},
#    'yotel-dubai-milestones': {'Estimated Handover Date': 'Q3 2018',
#     'Construction Started': 'August 2016'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '16 mins drive',
#     'Al Maktoum International Airport': '42 mins drive',
#     'La Mer by Meraas': '15 mins drive',
#     'Mall of the Emirates': '12 mins drive',
#     'Dubai Mall': '10 mins drive',
#     'Burj Al Arab': '15 mins drive',
#     'Ibn Battuta Mall': '21 mins drive',
#     'The Walk JBR': '20 mins drive',
#     'Dubai International Airport': '18 mins drive'}},
#   'coordinates': '25°11 15.8"N 55°15 29.7"E',
#   'last_photo_update': {'caption': 'Yotel Dubai, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/yotel-dubai-28576_xl.jpg'}},
#  '303': {'url': 'https://propsearch.ae/dubai/west-bay-tower',
#   'tables': {'west-bay-tower-key-information': {'Location type': 'Residential building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '34',
#     'Floors below ground': '4',
#     'Building type': 'Skyscraper',
#     'Total units': '252',
#     'Unit types': '24 studios78 one-bedroom apartments120 two-bedroom apartments30 three-bedroom apartments'},
#    'companies-associated-with-west-bay-tower': {'Developer': 'Orion Real Estate Development',
#     'Project Manager': 'Bonyan International Investment Group Holding',
#     'Architectural Consultant': 'National Engineering Bureau',
#     'Contractor': 'Gulf Technical Construction Company',
#     'Piling Contractor': 'Geo Foundation Group'},
#    'west-bay-tower-milestones': {'Estimated Handover Date': '2009',
#     'Revised Estimated Handover Date': 'December 2019',
#     'Construction Started': 'October 2018'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '20 mins drive',
#     'Al Maktoum International Airport': '44 mins drive',
#     'La Mer by Meraas': '19 mins drive',
#     'Mall of the Emirates': '16 mins drive',
#     'Dubai Mall': '9 mins drive',
#     'Burj Al Arab': '19 mins drive',
#     'Ibn Battuta Mall': '24 mins drive',
#     'The Walk JBR': '24 mins drive',
#     'Dubai International Airport': '19 mins drive'}},
#   'coordinates': '25°11 5"N 55°15 48.1"E',
#   'last_photo_update': {'caption': 'West Bay Tower, construction site signboard.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/west-bay-tower-28630_xl.jpg'}},
#  '306': {'url': 'https://propsearch.ae/dubai/waterfall-tower',
#   'tables': {'waterfall-tower-key-information': {'Location type': 'Residential building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '22',
#     'Building type': 'High-rise building'},
#    'companies-associated-with-waterfall-tower': {'Developer': 'Faisal Muhsen Barakat',
#     'Architectural Consultant': 'Nàbito Architects'},
#    'waterfall-tower-milestones': {'Date Launched': '2017',
#     'Construction Started': '2017'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '20 mins drive',
#     'Al Maktoum International Airport': '40 mins drive',
#     'La Mer by Meraas': '17 mins drive',
#     'Mall of the Emirates': '16 mins drive',
#     'Dubai Mall': '9 mins drive',
#     'Burj Al Arab': '18 mins drive',
#     'Ibn Battuta Mall': '24 mins drive',
#     'The Walk JBR': '23 mins drive',
#     'Dubai International Airport': '17 mins drive'}},
#   'coordinates': '25°10 51"N 55°15 57.3"E',
#   'last_photo_update': {'caption': 'Waterfall Tower, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/waterfall-tower-28562_xl.jpg'}},
#  '312': {'url': 'https://propsearch.ae/dubai/vera-by-damac',
#   'tables': {'vera-by-damac-key-information': {'Location type': 'Residential building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '30',
#     'Building type': 'Skyscraper',
#     'Unit types': 'StudiosOne-bedroom apartmentsTwo-bedroom apartments'},
#    'companies-associated-with-vera-by-damac': {'Developer': 'Damac Properties',
#     'Architectural Consultant': 'U+A Architects',
#     'Contractor': 'Arabtec Construction',
#     'Piling Contractor': 'National Piling Company'},
#    'vera-by-damac-milestones': {'Date Launched': 'June 2016',
#     'Estimated Handover Date': '2018'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '22 mins drive',
#     'Al Maktoum International Airport': '43 mins drive',
#     'La Mer by Meraas': '19 mins drive',
#     'Mall of the Emirates': '17 mins drive',
#     'Dubai Mall': '9 mins drive',
#     'Burj Al Arab': '20 mins drive',
#     'Ibn Battuta Mall': '26 mins drive',
#     'The Walk JBR': '25 mins drive',
#     'Dubai International Airport': '16 mins drive'}},
#   'coordinates': '25°11 13.2"N 55°16 57.8"E',
#   'last_photo_update': {'caption': 'Vera by Damac, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/vera-by-damac-28606_xl.jpg'}}}

# %% [markdown]
# ## Save scrapped data (Business Bay) as json file
#
# Online json tutorial [link](https://www.freecodecamp.org/news/python-read-json-file-how-to-load-json-from-a-file-and-parse-dumps/)

# %%
import json

# save file
json_dump_name = 'business-bay-under-development'
data_to_dump = scrapped_dict
with open(json_dump_name + '.json', 'w') as file:
    json.dump(data_to_dump, file)

# %%
# load json file into dictionary
json_load_file_name = 'business-bay-under-development'
with open(json_load_file_name + '.json') as file:
    # Load its content and make a new dictionary
    loaded_json_data = json.load(file)

# %%
loaded_json_data
# Out:
# {'96': {'url': 'https://propsearch.ae/dubai/millennium-binghatti-residences',
#   'tables': {'millennium-binghatti-residences-key-information': {'Location type': 'Residential building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '24',
#     'Building type': 'High-rise building',
#     'Total units': '230',
#     'Unit types': '113 studios58 one-bedroom apartments59 two-bedroom apartments'},
#    'companies-associated-with-millennium-binghatti-residences': {'Developer': 'Binghatti Developers',
#     'Architectural Consultant': 'Eng. Adnan Saffarini',
#     'Contractor': 'Granada Europe Engineering Contracting Co.'},
#    'millennium-binghatti-residences-milestones': {'Date Launched': 'March 2018',
#     'Estimated Handover Date': 'Q4 2019',
#     'Construction Started': '2018'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '20 mins drive',
#     'Al Maktoum International Airport': '42 mins drive',
#     'La Mer by Meraas': '19 mins drive',
#     'Mall of the Emirates': '16 mins drive',
#     'Dubai Mall': '10 mins drive',
#     'Burj Al Arab': '19 mins drive',
#     'Ibn Battuta Mall': '24 mins drive',
#     'The Walk JBR': '24 mins drive',
#     'Dubai International Airport': '20 mins drive'}},
#   'coordinates': '25°10 51"N 55°16 8.8"E',
#   'last_photo_update': {'caption': 'Millennium Binghatti Residences, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/millennium-binghatti-residences-28556_xl.jpg'}},
#  '98': {'url': 'https://propsearch.ae/dubai/moon-tower',
#   'tables': {'moon-tower-key-information': {'Location type': 'Residential building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '20',
#     'Building type': 'High-rise building',
#     'Total units': '255',
#     'Unit types': 'StudiosOne-bedroom apartmentsTwo-bedroom apartments'},
#    'companies-associated-with-moon-tower': {'Developer': 'Arabia Group Investment Limited',
#     'Architectural Consultant': 'Chawla Architectural & Consulting Engineers'},
#    'moon-tower-milestones': {'Date Launched': '2007',
#     'Revised Estimated Handover Date': 'Q4 2016',
#     'Construction Started': '2009'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '21 mins drive',
#     'Al Maktoum International Airport': '42 mins drive',
#     'La Mer by Meraas': '20 mins drive',
#     'Mall of the Emirates': '16 mins drive',
#     'Dubai Mall': '13 mins drive',
#     'Burj Al Arab': '20 mins drive',
#     'Ibn Battuta Mall': '25 mins drive',
#     'The Walk JBR': '25 mins drive',
#     'Dubai International Airport': '20 mins drive'}},
#   'coordinates': '25°11 3.5"N 55°17 5.1"E',
#   'last_photo_update': {'caption': 'Moon Tower, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/moon-tower-28532_xl.jpg'}},
#  '99': {'url': 'https://propsearch.ae/dubai/movenpick-hotel-living',
#   'tables': {'mövenpick-hotel-&-living-key-information': {'Location type': 'Residential building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '36',
#     'Building type': 'Skyscraper',
#     'Total units': '403'},
#    'companies-associated-with-mövenpick-hotel-&-living': {'Developer': 'SAAS Properties',
#     'Architectural Consultant': 'National Engineering Bureau',
#     'Contractor': 'Kele Contracting'},
#    'mövenpick-hotel-&-living-milestones': {'Estimated Handover Date': 'Q4 2016',
#     'Construction Started': '2015'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '21 mins drive',
#     'Al Maktoum International Airport': '44 mins drive',
#     'La Mer by Meraas': '17 mins drive',
#     'Mall of the Emirates': '16 mins drive',
#     'Dubai Mall': '7 mins drive',
#     'Burj Al Arab': '19 mins drive',
#     'Ibn Battuta Mall': '25 mins drive',
#     'The Walk JBR': '24 mins drive',
#     'Dubai International Airport': '17 mins drive'}},
#   'coordinates': '25°11 19.6"N 55°16 13.1"E',
#   'last_photo_update': {'caption': 'Mövenpick Hotel Apartments Business Bay, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/movenpick-hotel-apartments-business-bay-28626_xl.jpg'}},
#  '108': {'url': 'https://propsearch.ae/dubai/nobles-residential-tower',
#   'tables': {'nobles-residential-tower-key-information': {'Location type': 'Residential building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '53',
#     'Floors below ground': '2',
#     'Building type': 'Skyscraper',
#     'Total units': '549',
#     'Unit types': '278 one-bedroom apartments239 two-bedroom apartments32 three-bedroom apartments'},
#    'companies-associated-with-nobles-residential-tower': {'Developer': 'Tiger Properties',
#     'Architectural Consultant': 'LACASA Architects & Engineering Consultants',
#     'Contractor': 'Tiger International General Contracting'},
#    'nobles-residential-tower-milestones': {'Date Launched': 'September 2017',
#     'Construction Started': '2019'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '22 mins drive',
#     'Al Maktoum International Airport': '43 mins drive',
#     'La Mer by Meraas': '18 mins drive',
#     'Mall of the Emirates': '18 mins drive',
#     'Dubai Mall': '10 mins drive',
#     'Burj Al Arab': '21 mins drive',
#     'Ibn Battuta Mall': '26 mins drive',
#     'The Walk JBR': '26 mins drive',
#     'Dubai International Airport': '16 mins drive'}},
#   'coordinates': '25°11 4.5"N 55°17 24.8"E',
#   'last_photo_update': {'caption': 'Nobles Residential Tower, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/nobles-residential-tower-28522_xl.jpg'}},
#  '110': {'url': 'https://propsearch.ae/dubai/marble-arch-tower',
#   'tables': {'marble-arch-tower-key-information': {'Location type': 'Residential building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development'},
#    'companies-associated-with-marble-arch-tower': {'Architectural Consultant': 'DXB Design Studio',
#     'Contractor': 'Modern Executive Systems Contracting',
#     'Piling Contractor': 'Geo Foundation Group'},
#    'marble-arch-tower-milestones': {'Construction Started': '2019'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '19 mins drive',
#     'Al Maktoum International Airport': '42 mins drive',
#     'La Mer by Meraas': '17 mins drive',
#     'Mall of the Emirates': '14 mins drive',
#     'Dubai Mall': '11 mins drive',
#     'Burj Al Arab': '17 mins drive',
#     'Ibn Battuta Mall': '22 mins drive',
#     'The Walk JBR': '22 mins drive',
#     'Dubai International Airport': '19 mins drive'}},
#   'coordinates': '25°10 46.8"N 55°15 53.9"E',
#   'last_photo_update': {'caption': 'Marble Arch Tower, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/marble-arch-tower-28563_xl.jpg'}},
#  '118': {'url': 'https://propsearch.ae/dubai/mama-shelter-dubai',
#   'tables': {'mama-shelter-dubai-key-information': {'Location type': 'Mixed-use building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '25',
#     'Floors below ground': '3',
#     'Building type': 'Skyscraper',
#     'Total units': '201'},
#    'companies-associated-with-mama-shelter-dubai': {'Developer': 'Kappa Acca Real Estate Development',
#     'Owner': 'Khamas Group of Investment Companies',
#     'Architectural Consultant': 'Franklin Azzi Architecture',
#     'Contractor': 'CRC Engineering Company LLC',
#     'Piling Contractor': 'TMF Euro Foundations'},
#    'mama-shelter-dubai-milestones': {'Date Launched': 'May 2017',
#     'Estimated Handover Date': '2020',
#     'Construction Started': '2018'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '21 mins drive',
#     'Al Maktoum International Airport': '42 mins drive',
#     'La Mer by Meraas': '20 mins drive',
#     'Mall of the Emirates': '16 mins drive',
#     'Dubai Mall': '11 mins drive',
#     'Burj Al Arab': '20 mins drive',
#     'Ibn Battuta Mall': '25 mins drive',
#     'The Walk JBR': '24 mins drive',
#     'Dubai International Airport': '21 mins drive'}},
#   'coordinates': '25°10 48.3"N 55°16 18.9"E',
#   'last_photo_update': {'caption': 'Mama Shelter Dubai, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/mama-shelter-dubai-28548_xl.jpg'}},
#  '121': {'url': 'https://propsearch.ae/dubai/lillian-tower',
#   'tables': {'lillian-tower-key-information': {'Location type': 'Mixed-use building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '30',
#     'Floors below ground': '3',
#     'Building type': 'Skyscraper',
#     'Total units': '583'},
#    'companies-associated-with-lillian-tower': {'Developer': 'Marya Investments'},
#    'lillian-tower-milestones': {'Date Launched': '2007',
#     'Estimated Handover Date': '2016'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '18 mins drive',
#     'Al Maktoum International Airport': '42 mins drive',
#     'La Mer by Meraas': '17 mins drive',
#     'Mall of the Emirates': '13 mins drive',
#     'Dubai Mall': '7 mins drive',
#     'Burj Al Arab': '16 mins drive',
#     'Ibn Battuta Mall': '22 mins drive',
#     'The Walk JBR': '21 mins drive',
#     'Dubai International Airport': '18 mins drive'}},
#   'coordinates': '25°11 14.3"N 55°15 45.4"E',
#   'last_photo_update': {'caption': 'Lillian Tower, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/lillian-tower-28578_xl.jpg'}},
#  '133': {'url': 'https://propsearch.ae/dubai/ag-tower-business-bay',
#   'tables': {'ag-tower-business-bay-key-information': {'Location type': 'Residential building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '29',
#     'Building type': 'Skyscraper',
#     'Total units': '437',
#     'Unit types': 'One-bedroom apartmentsTwo-bedroom apartmentsThree-bedroom apartments'},
#    'companies-associated-with-ag-tower-business-bay': {'Developer': 'Arabian Gulf Properties',
#     'Financier': 'Emirates NBD',
#     'Architectural Consultant': 'CVTEC Consulting Engineers',
#     'Contractor': 'Beijing Emirates International Construction Co.',
#     'MEP Consultant': 'City Compass Electromechanical'},
#    'ag-tower-business-bay-milestones': {'Date Launched': '2015',
#     'Construction Started': '2016'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '18 mins drive',
#     'Al Maktoum International Airport': '38 mins drive',
#     'La Mer by Meraas': '17 mins drive',
#     'Mall of the Emirates': '14 mins drive',
#     'Dubai Mall': '10 mins drive',
#     'Burj Al Arab': '17 mins drive',
#     'Ibn Battuta Mall': '22 mins drive',
#     'The Walk JBR': '22 mins drive',
#     'Dubai International Airport': '18 mins drive'}},
#   'coordinates': '25°10 47.6"N 55°16 8.9"E',
#   'last_photo_update': {'caption': 'AG Tower Business Bay, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/ag-tower-business-bay-28560_xl.jpg'}},
#  '134': {'url': 'https://propsearch.ae/dubai/ahad-residences',
#   'tables': {'ahad-residences-key-information': {'Location type': 'Residential building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '31',
#     'Floors below ground': '5',
#     'Building type': 'Skyscraper'},
#    'companies-associated-with-ahad-residences': {'Developer': 'Mercury Investment Holding',
#     'Architectural Consultant': 'VX Architects',
#     'Interior Designer': 'Opaal',
#     'Contractor': 'Evan Lim Penta Construction LLC'},
#    'ahad-residences-milestones': {'Date Launched': '2017',
#     'Construction Started': '2018'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '22 mins drive',
#     'Al Maktoum International Airport': '46 mins drive',
#     'La Mer by Meraas': '19 mins drive',
#     'Mall of the Emirates': '18 mins drive',
#     'Dubai Mall': '8 mins drive',
#     'Burj Al Arab': '21 mins drive',
#     'Ibn Battuta Mall': '26 mins drive',
#     'The Walk JBR': '26 mins drive',
#     'Dubai International Airport': '19 mins drive'}},
#   'coordinates': '25°11 12"N 55°15 57.6"E',
#   'last_photo_update': {'caption': 'Ahad Residences, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/ahad-residences-28628_xl.jpg'}},
#  '140': {'url': 'https://propsearch.ae/dubai/paramount-tower-hotel-residences',
#   'tables': {'paramount-tower-hotel-&-residences-key-information': {'Location type': 'Mixed-use building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '66',
#     'Building type': 'Skyscraper',
#     'Total units': '826'},
#    'companies-associated-with-paramount-tower-hotel-&-residences': {'Developer': 'Damac Properties',
#     'Architectural Consultant': 'LACASA Architects & Engineering Consultants'},
#    'paramount-tower-hotel-&-residences-milestones': {'Date Launched': 'September 2014',
#     'Estimated Handover Date': 'Q3 2019',
#     'Construction Started': '2015'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '21 mins drive',
#     'Al Maktoum International Airport': '46 mins drive',
#     'La Mer by Meraas': '15 mins drive',
#     'Mall of the Emirates': '16 mins drive',
#     'Dubai Mall': '7 mins drive',
#     'Burj Al Arab': '19 mins drive',
#     'Ibn Battuta Mall': '25 mins drive',
#     'The Walk JBR': '24 mins drive',
#     'Dubai International Airport': '15 mins drive'}},
#   'coordinates': '25°11 36.3"N 55°15 55.3"E',
#   'last_photo_update': {'caption': 'Paramount Tower Hotel &amp; Residences, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/paramount-tower-hotel-residences-28638_xl.jpg'}},
#  '144': {'url': 'https://propsearch.ae/dubai/amna-tower',
#   'tables': {'amna-tower-key-information': {'Location type': 'Residential building',
#     'Area': 'Al Habtoor City',
#     'Phase': 'Under development',
#     'Floors': '52',
#     'Height': '307 metres (1,007 feet)',
#     'Building type': 'Skyscraper',
#     'Total units': '537',
#     'Unit types': 'One-bedroom apartmentsTwo-bedroom apartmentsThree-bedroom apartmentsFour-bedroom apartmentsFive-bedroom apartmentsSix-bedroom apartmentsPenthouses'},
#    'companies-associated-with-amna-tower': {'Developer': 'Al Habtoor Group',
#     'Architectural Consultant': 'WS Atkins & Partners'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '18 mins drive',
#     'Al Maktoum International Airport': '40 mins drive',
#     'La Mer by Meraas': '14 mins drive',
#     'Mall of the Emirates': '13 mins drive',
#     'Dubai Mall': '10 mins drive',
#     'Burj Al Arab': '16 mins drive',
#     'Ibn Battuta Mall': '21 mins drive',
#     'The Walk JBR': '21 mins drive',
#     'Dubai International Airport': '18 mins drive'}},
#   'coordinates': '25°10 57.2"N 55°15 20.6"E',
#   'last_photo_update': {'caption': 'Amna Tower, construction update July 2020.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/amna-tower-22350_xl.jpg'}},
#  '158': {'url': 'https://propsearch.ae/dubai/kingston-towers-business-bay',
#   'tables': {'kingston-towers-business-bay-key-information': {'Location type': 'Multi-building complex',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors below ground': '2'},
#    'companies-associated-with-kingston-towers-business-bay': {'Developer': 'Kingston',
#     'Project Manager': 'Faithful & Gould',
#     'Architectural Consultant': 'Canadian Consultant',
#     'Engineering Consultant': 'MAK Consultancy & Architects',
#     'Contractor': 'Gulf Asia Contracting',
#     'Piling Contractor': 'Delta Foundations Co.'},
#    'kingston-towers-business-bay-milestones': {'Date Launched': '2018',
#     'Construction Started': '2019'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '18 mins drive',
#     'Al Maktoum International Airport': '39 mins drive',
#     'La Mer by Meraas': '17 mins drive',
#     'Mall of the Emirates': '14 mins drive',
#     'Dubai Mall': '9 mins drive',
#     'Burj Al Arab': '17 mins drive',
#     'Ibn Battuta Mall': '21 mins drive',
#     'The Walk JBR': '22 mins drive',
#     'Dubai International Airport': '16 mins drive'}},
#   'coordinates': '25°10 49.8"N 55°16 42.1"E',
#   'last_photo_update': {'caption': 'Kingston Towers Business Bay, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/kingston-towers-business-bay-28538_xl.jpg'}},
#  '167': {'url': 'https://propsearch.ae/dubai/sky-bay-hotel',
#   'tables': {'sky-bay-hotel-key-information': {'Location type': 'Hotel',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '18',
#     'Building type': 'High-rise building',
#     'Total units': '440',
#     'Unit types': '440 hotel rooms'},
#    'companies-associated-with-sky-bay-hotel': {'Developer': 'The First Group',
#     'Architectural Consultant': 'Alajmi Engineering Consultants',
#     'Contractor': 'Al Habbai Contracting LLC'},
#    'sky-bay-hotel-milestones': {'Construction Started': '2016'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '18 mins drive',
#     'Al Maktoum International Airport': '40 mins drive',
#     'La Mer by Meraas': '17 mins drive',
#     'Mall of the Emirates': '14 mins drive',
#     'Dubai Mall': '10 mins drive',
#     'Burj Al Arab': '17 mins drive',
#     'Ibn Battuta Mall': '21 mins drive',
#     'The Walk JBR': '22 mins drive',
#     'Dubai International Airport': '18 mins drive'}},
#   'coordinates': '25°10 41.3"N 55°16 4.7"E',
#   'last_photo_update': {'caption': 'Sky Bay Hotel, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/sky-bay-hotel-28565_xl.jpg'}},
#  '173': {'url': 'https://propsearch.ae/dubai/safeer-tower-3',
#   'tables': {'safeer-tower-3-key-information': {'Location type': 'Residential building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '20',
#     'Floors below ground': '1',
#     'Building type': 'High-rise building'},
#    'companies-associated-with-safeer-tower-3': {'Developer': 'Al Seeb Real Estate Development',
#     'Architectural Consultant': 'National Engineering Bureau',
#     'Contractor': 'Rose City Contracting LLC'},
#    'safeer-tower-3-milestones': {'Date Launched': '2018',
#     'Construction Started': '2019'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '19 mins drive',
#     'Al Maktoum International Airport': '39 mins drive',
#     'La Mer by Meraas': '17 mins drive',
#     'Mall of the Emirates': '14 mins drive',
#     'Dubai Mall': '10 mins drive',
#     'Burj Al Arab': '17 mins drive',
#     'Ibn Battuta Mall': '22 mins drive',
#     'The Walk JBR': '22 mins drive',
#     'Dubai International Airport': '16 mins drive'}},
#   'coordinates': '25°10 47.6"N 55°16 40.4"E',
#   'last_photo_update': {'caption': 'Safeer Tower 3, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/safeer-tower-3-28541_xl.jpg'}},
#  '177': {'url': 'https://propsearch.ae/dubai/ritz-carlton-hotel-apartments',
#   'tables': {'ritz-carlton-hotel-apartments-key-information': {'Location type': 'Hotel apartments building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development'},
#    'companies-associated-with-ritz-carlton-hotel-apartments': {'Developer': 'Kappa Acca Real Estate Development',
#     'Owner': 'Khamas Group of Investment Companies',
#     'Architectural Consultant': 'National Engineering Bureau',
#     'Contractor': 'AIC Contracting'},
#    'ritz-carlton-hotel-apartments-milestones': {'Date Launched': 'Q1 2021'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '20 mins drive',
#     'Al Maktoum International Airport': '38 mins drive',
#     'La Mer by Meraas': '20 mins drive',
#     'Mall of the Emirates': '15 mins drive',
#     'Dubai Mall': '12 mins drive',
#     'Burj Al Arab': '18 mins drive',
#     'Ibn Battuta Mall': '23 mins drive',
#     'The Walk JBR': '24 mins drive',
#     'Dubai International Airport': '20 mins drive'}},
#   'coordinates': '25°11 4.7"N 55°17 6.4"E',
#   'last_photo_update': {'caption': 'Ritz Carlton Hotel Apartments, construction site signboard.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/ritz-carlton-hotel-apartments-28528_xl.jpg'}},
#  '178': {'url': 'https://propsearch.ae/dubai/reva-by-damac',
#   'tables': {'reva-by-damac-key-information': {'Location type': 'Multi-building complex',
#     'Area': 'Business Bay',
#     'Phase': 'Under development'},
#    'companies-associated-with-reva-by-damac': {'Developer': 'Damac Properties',
#     'Architectural Consultant': 'U+A Architects',
#     'Contractor': 'Arabtec Construction',
#     'Piling Contractor': 'National Piling Company'},
#    'reva-by-damac-milestones': {'Date Launched': 'January 2018',
#     'Construction Started': '2018'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '22 mins drive',
#     'Al Maktoum International Airport': '44 mins drive',
#     'La Mer by Meraas': '19 mins drive',
#     'Mall of the Emirates': '18 mins drive',
#     'Dubai Mall': '9 mins drive',
#     'Burj Al Arab': '21 mins drive',
#     'Ibn Battuta Mall': '26 mins drive',
#     'The Walk JBR': '26 mins drive',
#     'Dubai International Airport': '16 mins drive'}},
#   'coordinates': '25°11 16"N 55°16 59.1"E',
#   'last_photo_update': {'caption': 'Reva by Damac, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/reva-by-damac-28605_xl.jpg'}},
#  '185': {'url': 'https://propsearch.ae/dubai/ramee-grand-hotel-spa',
#   'tables': {'ramee-grand-hotel-&-spa-key-information': {'Location type': 'Hotel',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '20',
#     'Floors below ground': '4',
#     'Building type': 'High-rise building'},
#    'companies-associated-with-ramee-grand-hotel-&-spa': {'Developer': 'Ramee Group',
#     'Architectural Consultant': 'Archgroup Consultants',
#     'Contractor': 'Delta Al Wadi Contracting',
#     'Piling Contractor': 'Delta Foundations Co.'},
#    'ramee-grand-hotel-&-spa-milestones': {'Date Launched': '2017',
#     'Construction Started': '2018'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '20 mins drive',
#     'Al Maktoum International Airport': '42 mins drive',
#     'La Mer by Meraas': '17 mins drive',
#     'Mall of the Emirates': '15 mins drive',
#     'Dubai Mall': '8 mins drive',
#     'Burj Al Arab': '19 mins drive',
#     'Ibn Battuta Mall': '24 mins drive',
#     'The Walk JBR': '23 mins drive',
#     'Dubai International Airport': '14 mins drive'}},
#   'coordinates': '25°11 17.2"N 55°16 53.6"E',
#   'last_photo_update': {'caption': 'Ramee Grand Hotel &amp; Spa, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/ramee-grand-hotel-spa-28593_xl.jpg'}},
#  '189': {'url': 'https://propsearch.ae/dubai/srg-holding-hotel-business-bay',
#   'tables': {'srg-holding-hotel-business-bay-key-information': {'Location type': 'Mixed-use building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '29',
#     'Floors below ground': '1',
#     'Building type': 'Skyscraper'},
#    'companies-associated-with-srg-holding-hotel-business-bay': {'Developer': 'SRG Holding Limited',
#     'Architectural Consultant': 'ERGA Progress Engineering Consultants',
#     'Contractor': 'Al Habbai Contracting LLC'},
#    'srg-holding-hotel-business-bay-milestones': {'Date Launched': '2018',
#     'Construction Started': '2018'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '23 mins drive',
#     'Al Maktoum International Airport': '43 mins drive',
#     'La Mer by Meraas': '19 mins drive',
#     'Mall of the Emirates': '18 mins drive',
#     'Dubai Mall': '10 mins drive',
#     'Burj Al Arab': '21 mins drive',
#     'Ibn Battuta Mall': '26 mins drive',
#     'The Walk JBR': '26 mins drive',
#     'Dubai International Airport': '17 mins drive'}},
#   'coordinates': '25°11 6"N 55°17 23.1"E',
#   'last_photo_update': {'caption': 'SRG Holding Hotel Business Bay, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/srg-holding-hotel-business-bay-28521_xl.jpg'}},
#  '192': {'url': 'https://propsearch.ae/dubai/kempinski-business-bay',
#   'tables': {'kempinski-business-bay-key-information': {'Location type': 'Hotel',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '25',
#     'Building type': 'Skyscraper',
#     'Total units': '240',
#     'Unit types': '240 hotel rooms'},
#    'companies-associated-with-kempinski-business-bay': {'Developer': 'Seastar Properties Limited',
#     'Architectural Consultant': 'National Engineering Bureau'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '20 mins drive',
#     'Al Maktoum International Airport': '40 mins drive',
#     'La Mer by Meraas': '18 mins drive',
#     'Mall of the Emirates': '15 mins drive',
#     'Dubai Mall': '12 mins drive',
#     'Burj Al Arab': '18 mins drive',
#     'Ibn Battuta Mall': '24 mins drive',
#     'The Walk JBR': '23 mins drive',
#     'Dubai International Airport': '20 mins drive'}},
#   'coordinates': '25°10 54.3"N 55°16 45.1"E',
#   'last_photo_update': {'caption': 'Kempinski Business Bay, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/kempinski-business-bay-28611_xl.jpg'}},
#  '193': {'url': 'https://propsearch.ae/dubai/kasco-tower',
#   'tables': {'kasco-tower-key-information': {'Location type': 'Residential building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '23',
#     'Floors below ground': '2',
#     'Building type': 'High-rise building'},
#    'companies-associated-with-kasco-tower': {'Developer': 'Ahmed Al Janabi',
#     'Architectural Consultant': 'Next Engineering Consultants',
#     'Contractor': 'Sumer Contracting Company'},
#    'kasco-tower-milestones': {'Date Launched': '2018',
#     'Construction Started': '2018'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '21 mins drive',
#     'Al Maktoum International Airport': '42 mins drive',
#     'La Mer by Meraas': '19 mins drive',
#     'Mall of the Emirates': '16 mins drive',
#     'Dubai Mall': '12 mins drive',
#     'Burj Al Arab': '19 mins drive',
#     'Ibn Battuta Mall': '25 mins drive',
#     'The Walk JBR': '24 mins drive',
#     'Dubai International Airport': '21 mins drive'}},
#   'coordinates': '25°11 0.9"N 55°17 2.5"E',
#   'last_photo_update': {'caption': 'Kasco Tower, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/kasco-tower-28531_xl.jpg'}},
#  '196': {'url': 'https://propsearch.ae/dubai/j-one',
#   'tables': {'j-one-key-information': {'Location type': 'Multi-building complex',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Total units': '347'},
#    'companies-associated-with-j-one': {'Developer': 'RKM Real Estate LLC',
#     'Financier': 'Commercial Bank of Dubai',
#     'Architectural Consultant': 'QHC Architects & Engineers LLC',
#     'Contractor': 'Ali & Sons Contracting'},
#    'j-one-milestones': {'Date Launched': 'August 2017',
#     'Construction Started': '2017'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '20 mins drive',
#     'Al Maktoum International Airport': '42 mins drive',
#     'La Mer by Meraas': '18 mins drive',
#     'Mall of the Emirates': '15 mins drive',
#     'Dubai Mall': '8 mins drive',
#     'Burj Al Arab': '19 mins drive',
#     'Ibn Battuta Mall': '24 mins drive',
#     'The Walk JBR': '24 mins drive',
#     'Dubai International Airport': '15 mins drive'}},
#   'coordinates': '25°11 10.3"N 55°17 0"E',
#   'last_photo_update': {'caption': 'J One, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/j-one-28607_xl.jpg'}},
#  '209': {'url': 'https://propsearch.ae/dubai/the-court-tower',
#   'tables': {'the-court-tower-key-information': {'Location type': 'Office building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '30',
#     'Building type': 'Skyscraper'},
#    'companies-associated-with-the-court-tower': {'Developer': 'Tanmiyat Global',
#     'Architectural Consultant': 'Al Hazmi & Associates Consultant'},
#    'the-court-tower-milestones': {'Date Launched': '2005',
#     'Construction Started': '2006'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '20 mins drive',
#     'Al Maktoum International Airport': '43 mins drive',
#     'La Mer by Meraas': '15 mins drive',
#     'Mall of the Emirates': '16 mins drive',
#     'Dubai Mall': '7 mins drive',
#     'Burj Al Arab': '19 mins drive',
#     'Ibn Battuta Mall': '24 mins drive',
#     'The Walk JBR': '24 mins drive',
#     'Dubai International Airport': '16 mins drive'}},
#   'coordinates': '25°11 4.8"N 55°15 31.8"E',
#   'last_photo_update': {'caption': 'The Court Tower, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/the-court-tower-28572_xl.jpg'}},
#  '219': {'url': 'https://propsearch.ae/dubai/the-one-hotel-business-bay',
#   'tables': {'the-one-hotel-business-bay-key-information': {'Location type': 'Hotel',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '18',
#     'Floors below ground': '2',
#     'Building type': 'High-rise building',
#     'Total units': '492',
#     'Unit types': '492 hotel rooms'},
#    'companies-associated-with-the-one-hotel-business-bay': {'Developer': 'The First Group',
#     'Architectural Consultant': 'Engineering Consultants Group',
#     'Contractor': 'China Railway 18th Bureau Group',
#     'Piling Contractor': 'Stromek Emirates Foundations',
#     'MEP Consultant': 'Heat & Power Turnkey MEP Solutions'},
#    'the-one-hotel-business-bay-milestones': {'Date Launched': 'July 2016',
#     'Construction Started': '2017'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '19 mins drive',
#     'Al Maktoum International Airport': '39 mins drive',
#     'La Mer by Meraas': '17 mins drive',
#     'Mall of the Emirates': '14 mins drive',
#     'Dubai Mall': '10 mins drive',
#     'Burj Al Arab': '17 mins drive',
#     'Ibn Battuta Mall': '23 mins drive',
#     'The Walk JBR': '22 mins drive',
#     'Dubai International Airport': '17 mins drive'}},
#   'coordinates': '25°10 44.3"N 55°16 32.8"E',
#   'last_photo_update': {'caption': 'The One Hotel Business Bay, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/the-one-hotel-business-bay-28543_xl.jpg'}},
#  '233': {'url': 'https://propsearch.ae/dubai/dorchester-hotel-dubai',
#   'tables': {'dorchester-hotel-dubai-key-information': {'Location type': 'Hotel',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '32',
#     'Floors below ground': '2',
#     'Building type': 'Skyscraper'},
#    'companies-associated-with-dorchester-hotel-dubai': {'Developer': 'Sky Palaces Real Estate',
#     'Financier': 'Ajman Bank',
#     'Architectural Consultant': 'Foster + Partners',
#     'Contractor': 'Roberts Constructions',
#     'Piling Contractor': 'NSCC International'},
#    'dorchester-hotel-dubai-milestones': {'Date Launched': '2017',
#     'Estimated Handover Date': '2020',
#     'Construction Started': '2017'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '22 mins drive',
#     'Al Maktoum International Airport': '42 mins drive',
#     'La Mer by Meraas': '20 mins drive',
#     'Mall of the Emirates': '17 mins drive',
#     'Dubai Mall': '13 mins drive',
#     'Burj Al Arab': '20 mins drive',
#     'Ibn Battuta Mall': '26 mins drive',
#     'The Walk JBR': '25 mins drive',
#     'Dubai International Airport': '22 mins drive'}},
#   'coordinates': '25°11 16.3"N 55°17 17.6"E',
#   'last_photo_update': {'caption': 'Dorchester Hotel Dubai, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/dorchester-hotel-dubai-28550_xl.jpg'}},
#  '243': {'url': 'https://propsearch.ae/dubai/dolphin-tower',
#   'tables': {'dolphin-tower-key-information': {'Location type': 'Hotel apartments building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '22',
#     'Building type': 'High-rise building',
#     'Total units': '330',
#     'Unit types': '330 hotel rooms'},
#    'companies-associated-with-dolphin-tower': {'Owner': 'Farida Farnood',
#     'Hotel Operator': 'The First Group',
#     'Architectural Consultant': 'Arab Experts Engineering Consultants',
#     'Contractor': 'Modern Executive Systems Contracting'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '20 mins drive',
#     'Al Maktoum International Airport': '40 mins drive',
#     'La Mer by Meraas': '19 mins drive',
#     'Mall of the Emirates': '16 mins drive',
#     'Dubai Mall': '12 mins drive',
#     'Burj Al Arab': '19 mins drive',
#     'Ibn Battuta Mall': '24 mins drive',
#     'The Walk JBR': '24 mins drive',
#     'Dubai International Airport': '20 mins drive'}},
#   'coordinates': '25°10 59.1"N 55°16 59.4"E',
#   'last_photo_update': {'caption': 'Dolphin Tower, construction update January 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/dolphin-tower-26490_xl.jpg'}},
#  '285': {'url': 'https://propsearch.ae/dubai/bayz-by-danube',
#   'tables': {'bayz-by-danube-key-information': {'Location type': 'Residential building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '30',
#     'Building type': 'Skyscraper',
#     'Total units': '456',
#     'Unit types': '264 studios120 one-bedroom apartments48 two-bedroom apartments24 three-bedroom apartments'},
#    'companies-associated-with-bayz-by-danube': {'Developer': 'Danube Properties Development LLC',
#     'Architectural Consultant': 'National Engineering Bureau',
#     'Contractor': 'RAQ Contracting Co LLC'},
#    'bayz-by-danube-milestones': {'Date Launched': 'May 2017',
#     'Construction Started': '2018'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '18 mins drive',
#     'Al Maktoum International Airport': '38 mins drive',
#     'La Mer by Meraas': '17 mins drive',
#     'Mall of the Emirates': '14 mins drive',
#     'Dubai Mall': '9 mins drive',
#     'Burj Al Arab': '17 mins drive',
#     'Ibn Battuta Mall': '22 mins drive',
#     'The Walk JBR': '22 mins drive',
#     'Dubai International Airport': '16 mins drive'}},
#   'coordinates': '25°10 50.5"N 55°16 45.5"E',
#   'last_photo_update': {'caption': 'Bayz by Danube, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/bayz-by-danube-28539_xl.jpg'}},
#  '291': {'url': 'https://propsearch.ae/dubai/corporate-bay-tower',
#   'tables': {'corporate-bay-tower-key-information': {'Location type': 'Office building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '30',
#     'Floors below ground': '5',
#     'Building type': 'Skyscraper'},
#    'companies-associated-with-corporate-bay-tower': {'Developer': 'Goldline Real Estate Development LLC',
#     'Architectural Consultant': 'Em Square Engineering Consultants',
#     'Contractor': 'China State Construction Engineering Corporation'},
#    'corporate-bay-tower-milestones': {'Construction Started': '2007'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '20 mins drive',
#     'Al Maktoum International Airport': '44 mins drive',
#     'La Mer by Meraas': '19 mins drive',
#     'Mall of the Emirates': '15 mins drive',
#     'Dubai Mall': '10 mins drive',
#     'Burj Al Arab': '19 mins drive',
#     'Ibn Battuta Mall': '24 mins drive',
#     'The Walk JBR': '24 mins drive',
#     'Dubai International Airport': '19 mins drive'}},
#   'coordinates': '25°11 5.3"N 55°15 40.1"E',
#   'last_photo_update': {'caption': 'Corporate Bay Tower, construction update January 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/corporate-bay-tower-26537_xl.jpg'}},
#  '295': {'url': 'https://propsearch.ae/dubai/tiara-united-towers',
#   'tables': {'tiara-united-towers-key-information': {'Location type': 'Multi-building complex',
#     'Area': 'Business Bay',
#     'Phase': 'Under development'},
#    'companies-associated-with-tiara-united-towers': {'Developer': 'Zabeel Investments'},
#    'tiara-united-towers-milestones': {'Construction Started': '2006'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '17 mins drive',
#     'Al Maktoum International Airport': '42 mins drive',
#     'La Mer by Meraas': '15 mins drive',
#     'Mall of the Emirates': '12 mins drive',
#     'Dubai Mall': '10 mins drive',
#     'Burj Al Arab': '15 mins drive',
#     'Ibn Battuta Mall': '21 mins drive',
#     'The Walk JBR': '20 mins drive',
#     'Dubai International Airport': '18 mins drive'}},
#   'coordinates': '25°11 19.8"N 55°15 35.7"E',
#   'last_photo_update': {'caption': 'Tiara United Towers, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/tiara-united-towers-28577_xl.jpg'}},
#  '296': {'url': 'https://propsearch.ae/dubai/commercial-residential-tower-plot-3460763',
#   'tables': {'commercial-&-residential-tower-plot-3460763-key-information': {'Location type': 'Residential building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '21',
#     'Floors below ground': '2',
#     'Building type': 'High-rise building'},
#    'companies-associated-with-commercial-&-residential-tower-plot-3460763': {'Architectural Consultant': 'Art Consultants Dubai',
#     'Contractor': 'Gulf Asia Contracting',
#     'Piling Contractor': 'Edrafor Piling And Special Foundation'},
#    'commercial-&-residential-tower-plot-3460763-milestones': {'Construction Started': '2019'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '21 mins drive',
#     'Al Maktoum International Airport': '41 mins drive',
#     'La Mer by Meraas': '17 mins drive',
#     'Mall of the Emirates': '16 mins drive',
#     'Dubai Mall': '8 mins drive',
#     'Burj Al Arab': '19 mins drive',
#     'Ibn Battuta Mall': '24 mins drive',
#     'The Walk JBR': '24 mins drive',
#     'Dubai International Airport': '14 mins drive'}},
#   'coordinates': '25°11 25.9"N 55°17 27.7"E',
#   'last_photo_update': {'caption': 'Commercial &amp; Residential Tower Plot 3460763, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/commercial-residential-tower-plot-3460763-28516_xl.jpg'}},
#  '298': {'url': 'https://propsearch.ae/dubai/zada-tower',
#   'tables': {'zada-tower-key-information': {'Location type': 'Residential building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '30',
#     'Floors below ground': '4',
#     'Building type': 'Skyscraper',
#     'Total units': '699',
#     'Unit types': '699 one-bedroom apartments'},
#    'companies-associated-with-zada-tower': {'Developer': 'Damac Properties',
#     'Architectural Consultant': 'Kieferle & Partner',
#     'Contractor': 'Transemirates Contracting',
#     'Piling Contractor': 'National Piling Company'},
#    'zada-tower-milestones': {'Date Launched': 'April 2019'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '20 mins drive',
#     'Al Maktoum International Airport': '44 mins drive',
#     'La Mer by Meraas': '19 mins drive',
#     'Mall of the Emirates': '16 mins drive',
#     'Dubai Mall': '10 mins drive',
#     'Burj Al Arab': '19 mins drive',
#     'Ibn Battuta Mall': '24 mins drive',
#     'The Walk JBR': '24 mins drive',
#     'Dubai International Airport': '19 mins drive'}},
#   'coordinates': '25°11 4.6"N 55°15 42"E',
#   'last_photo_update': {'caption': 'Zada Tower, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/zada-tower-28566_xl.jpg'}},
#  '299': {'url': 'https://propsearch.ae/dubai/yotel-dubai',
#   'tables': {'yotel-dubai-key-information': {'Location type': 'Hotel',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '42',
#     'Building type': 'Skyscraper',
#     'Total units': '565',
#     'Unit types': '565 hotel rooms'},
#    'companies-associated-with-yotel-dubai': {'Developer': 'Dubai Investment Properties'},
#    'yotel-dubai-milestones': {'Estimated Handover Date': 'Q3 2018',
#     'Construction Started': 'August 2016'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '16 mins drive',
#     'Al Maktoum International Airport': '42 mins drive',
#     'La Mer by Meraas': '15 mins drive',
#     'Mall of the Emirates': '12 mins drive',
#     'Dubai Mall': '10 mins drive',
#     'Burj Al Arab': '15 mins drive',
#     'Ibn Battuta Mall': '21 mins drive',
#     'The Walk JBR': '20 mins drive',
#     'Dubai International Airport': '18 mins drive'}},
#   'coordinates': '25°11 15.8"N 55°15 29.7"E',
#   'last_photo_update': {'caption': 'Yotel Dubai, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/yotel-dubai-28576_xl.jpg'}},
#  '303': {'url': 'https://propsearch.ae/dubai/west-bay-tower',
#   'tables': {'west-bay-tower-key-information': {'Location type': 'Residential building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '34',
#     'Floors below ground': '4',
#     'Building type': 'Skyscraper',
#     'Total units': '252',
#     'Unit types': '24 studios78 one-bedroom apartments120 two-bedroom apartments30 three-bedroom apartments'},
#    'companies-associated-with-west-bay-tower': {'Developer': 'Orion Real Estate Development',
#     'Project Manager': 'Bonyan International Investment Group Holding',
#     'Architectural Consultant': 'National Engineering Bureau',
#     'Contractor': 'Gulf Technical Construction Company',
#     'Piling Contractor': 'Geo Foundation Group'},
#    'west-bay-tower-milestones': {'Estimated Handover Date': '2009',
#     'Revised Estimated Handover Date': 'December 2019',
#     'Construction Started': 'October 2018'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '20 mins drive',
#     'Al Maktoum International Airport': '44 mins drive',
#     'La Mer by Meraas': '19 mins drive',
#     'Mall of the Emirates': '16 mins drive',
#     'Dubai Mall': '9 mins drive',
#     'Burj Al Arab': '19 mins drive',
#     'Ibn Battuta Mall': '24 mins drive',
#     'The Walk JBR': '24 mins drive',
#     'Dubai International Airport': '19 mins drive'}},
#   'coordinates': '25°11 5"N 55°15 48.1"E',
#   'last_photo_update': {'caption': 'West Bay Tower, construction site signboard.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/west-bay-tower-28630_xl.jpg'}},
#  '306': {'url': 'https://propsearch.ae/dubai/waterfall-tower',
#   'tables': {'waterfall-tower-key-information': {'Location type': 'Residential building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '22',
#     'Building type': 'High-rise building'},
#    'companies-associated-with-waterfall-tower': {'Developer': 'Faisal Muhsen Barakat',
#     'Architectural Consultant': 'Nàbito Architects'},
#    'waterfall-tower-milestones': {'Date Launched': '2017',
#     'Construction Started': '2017'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '20 mins drive',
#     'Al Maktoum International Airport': '40 mins drive',
#     'La Mer by Meraas': '17 mins drive',
#     'Mall of the Emirates': '16 mins drive',
#     'Dubai Mall': '9 mins drive',
#     'Burj Al Arab': '18 mins drive',
#     'Ibn Battuta Mall': '24 mins drive',
#     'The Walk JBR': '23 mins drive',
#     'Dubai International Airport': '17 mins drive'}},
#   'coordinates': '25°10 51"N 55°15 57.3"E',
#   'last_photo_update': {'caption': 'Waterfall Tower, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/waterfall-tower-28562_xl.jpg'}},
#  '312': {'url': 'https://propsearch.ae/dubai/vera-by-damac',
#   'tables': {'vera-by-damac-key-information': {'Location type': 'Residential building',
#     'Area': 'Business Bay',
#     'Phase': 'Under development',
#     'Floors': '30',
#     'Building type': 'Skyscraper',
#     'Unit types': 'StudiosOne-bedroom apartmentsTwo-bedroom apartments'},
#    'companies-associated-with-vera-by-damac': {'Developer': 'Damac Properties',
#     'Architectural Consultant': 'U+A Architects',
#     'Contractor': 'Arabtec Construction',
#     'Piling Contractor': 'National Piling Company'},
#    'vera-by-damac-milestones': {'Date Launched': 'June 2016',
#     'Estimated Handover Date': '2018'},
#    'proximity-to-landmarks': {'Palm Jumeirah': '22 mins drive',
#     'Al Maktoum International Airport': '43 mins drive',
#     'La Mer by Meraas': '19 mins drive',
#     'Mall of the Emirates': '17 mins drive',
#     'Dubai Mall': '9 mins drive',
#     'Burj Al Arab': '20 mins drive',
#     'Ibn Battuta Mall': '26 mins drive',
#     'The Walk JBR': '25 mins drive',
#     'Dubai International Airport': '16 mins drive'}},
#   'coordinates': '25°11 13.2"N 55°16 57.8"E',
#   'last_photo_update': {'caption': 'Vera by Damac, construction update May 2021.',
#    'photo_url': 'https://static.propsearch.ae/dubai-locations/vera-by-damac-28606_xl.jpg'}}}

# %% [markdown]
# ### Build dataframe from scrapped data of projects

# %%
data_info_df = pd.DataFrame(loaded_json_data).T

# %%
data_info_df.head(2)
# Out:
#                                                   url  \
# 96  https://propsearch.ae/dubai/millennium-binghat...
# 98             https://propsearch.ae/dubai/moon-tower
#
#                                                tables  \
# 96  {'millennium-binghatti-residences-key-informat...
# 98  {'moon-tower-key-information': {'Location type...
#
#                 coordinates                                  last_photo_update
# 96   25°10 51"N 55°16 8.8"E  {'caption': 'Millennium Binghatti Residences, ...
# 98  25°11 3.5"N 55°17 5.1"E  {'caption': 'Moon Tower, construction update M...

# %%
# deserialized dataframe will have an 'object' type index, whereas the local copy is 'int64'
# reast deseralized index to match local, otherwise the concatenation operation returns nan values
data_info_df.index = data_info_df.index.astype('int64')
# concatenate dataframes
# bbay_on_dev_df: business bay under development
complete_df = pd.concat([bbay_on_dev_df, data_info_df], axis=1)
# drop duplicate url-link column
complete_df.drop(columns=['link'], inplace=True)

# %%
complete_df.head(2)
# Out:
#             area      sub_area                          project  \
# 96  Business Bay  Business Bay  Millennium Binghatti Residences
# 98  Business Bay  Business Bay                       Moon Tower
#
#                status                                                url  \
# 96  Under development  https://propsearch.ae/dubai/millennium-binghat...
# 98  Under development             https://propsearch.ae/dubai/moon-tower
#
#                                                tables  \
# 96  {'millennium-binghatti-residences-key-informat...
# 98  {'moon-tower-key-information': {'Location type...
#
#                 coordinates                                  last_photo_update
# 96   25°10 51"N 55°16 8.8"E  {'caption': 'Millennium Binghatti Residences, ...
# 98  25°11 3.5"N 55°17 5.1"E  {'caption': 'Moon Tower, construction update M...

# %% [markdown]
# ### Save full dataframe into csv

# %%
complete_df.to_csv('business-bay-under-development-merge.csv')

# %% [markdown]
# ### Load merged csv to dataframe
#
# CAVEAT: When loaded, data previously saved as a dictionary is cast as a string, which causes problems when trying to rename keys.  For this, either rename keys by using a dataframe built from loading the json file, not the loaded csv, or recast the necessary columns into dictionaries if you are using the loaded csv file.

# %%
complete_df = pd.read_csv('business-bay-under-development-merge.csv')

# %%
complete_df.head(2)
# Out:
#    Unnamed: 0          area      sub_area                          project  \
# 0          96  Business Bay  Business Bay  Millennium Binghatti Residences
# 1          98  Business Bay  Business Bay                       Moon Tower
#
#               status                                                url  \
# 0  Under development  https://propsearch.ae/dubai/millennium-binghat...
# 1  Under development             https://propsearch.ae/dubai/moon-tower
#
#                                               tables              coordinates  \
# 0  {'millennium-binghatti-residences-key-informat...   25°10 51"N 55°16 8.8"E
# 1  {'moon-tower-key-information': {'Location type...  25°11 3.5"N 55°17 5.1"E
#
#                                    last_photo_update
# 0  {'caption': 'Millennium Binghatti Residences, ...
# 1  {'caption': 'Moon Tower, construction update M...

# %% [markdown]
# ## Extract key pieces of data from the tables column
#
# This will surface data and place it in columns for easy referencing
# * Total Units
# * Developer name
# * Date Launched
# * Construction Started
# * Estimated Handover Date

# %% [markdown]
# #### Rename dictionary keys in tables column for easy referencing

# %%
# function that renames the keys in the tables to remove the project name
def rename_table_keys(table):
    # Input: table: contents of each rown on the tables column of the dataframe
    # eg transform: 'mama-shelter-dubai-key-information' -->  #'key-information'
    # extract all available keys
    key_ids = list(table)
    # iterate over keys and rename them to remove the project name from each and make them universal keys
    for key_id in key_ids:
        if 'key-information' in key_id:
            table['key-information'] = table.pop(key_id)
        elif 'companies-associated' in key_id:
            table['companies-associated'] = table.pop(key_id)
        elif  'milestones' in key_id:
            table['milestones'] = table.pop(key_id)
    return table

# %%
# make a deep copy of the loaded dataframe to make changes to it without modifying original
renamed_complete_df = complete_df.copy(deep=True)

# %%
# apply rename_table_keys function to rename keys in tables column for easy referencing
# this removes the project name from the key strings in each dictionary
renamed_complete_df.tables.apply(rename_table_keys);

# %%
renamed_complete_df.head(5)
# Out:
#              area      sub_area                          project  \
# 96   Business Bay  Business Bay  Millennium Binghatti Residences
# 98   Business Bay  Business Bay                       Moon Tower
# 99   Business Bay  Business Bay         Mövenpick Hotel & Living
# 108  Business Bay  Business Bay         Nobles Residential Tower
# 110  Business Bay  Business Bay                Marble Arch Tower
#
#                 status                                                url  \
# 96   Under development  https://propsearch.ae/dubai/millennium-binghat...
# 98   Under development             https://propsearch.ae/dubai/moon-tower
# 99   Under development  https://propsearch.ae/dubai/movenpick-hotel-li...
# 108  Under development  https://propsearch.ae/dubai/nobles-residential...
# 110  Under development      https://propsearch.ae/dubai/marble-arch-tower
#
#                                                 tables  \
# 96   {'proximity-to-landmarks': {'Palm Jumeirah': '...
# 98   {'proximity-to-landmarks': {'Palm Jumeirah': '...
# 99   {'proximity-to-landmarks': {'Palm Jumeirah': '...
# 108  {'proximity-to-landmarks': {'Palm Jumeirah': '...
# 110  {'proximity-to-landmarks': {'Palm Jumeirah': '...
#
#                    coordinates  \
# 96      25°10 51"N 55°16 8.8"E
# 98     25°11 3.5"N 55°17 5.1"E
# 99   25°11 19.6"N 55°16 13.1"E
# 108   25°11 4.5"N 55°17 24.8"E
# 110  25°10 46.8"N 55°15 53.9"E
#
#                                      last_photo_update
# 96   {'caption': 'Millennium Binghatti Residences, ...
# 98   {'caption': 'Moon Tower, construction update M...
# 99   {'caption': 'Mövenpick Hotel Apartments Busine...
# 108  {'caption': 'Nobles Residential Tower, constru...
# 110  {'caption': 'Marble Arch Tower, construction u...

# %% [markdown]
# #### Extract data from tables column and place into new columns

# %%
# For each table with data, extract the data into a dictionary which we will use to create dataframes
# each dataframe contains all table info for each row, which we will concatenate to the global dataframe
companies_associated = {}
key_information = {}
milestones = {}
last_photo = {}
for index, row in renamed_complete_df.iterrows():
    companies_associated[index] = row.tables.get('companies-associated', np.nan)
    key_information[index] = row.tables.get('key-information', np.nan)
    milestones[index] = row.tables.get('milestones', np.nan)
    last_photo[index] = row.last_photo_update

# %%
# build dataframes from the dictionaries created
companies_associated_df = pd.DataFrame(companies_associated).T
key_information_df = pd.DataFrame(key_information).T
milestones_df = pd.DataFrame(milestones).T
last_photo_df = pd.DataFrame(last_photo).T

# %%
# cluster all dataframes into a list for easy access
compound_df_list = [companies_associated_df, key_information_df, milestones_df, last_photo_df]

# %%
# lower case column name and use underscore as space separator
def lower_dash_column_rename(column_list):
    # transform to lower case and use undesrcore as word separator
    return [col.strip().lower().replace(' ', '_') for col in column_list]

# reaname columns
for df in compound_df_list:
    df.columns = lower_dash_column_rename(df.columns)

# %%
# since key_information_df has an area column which clashes in name with the original dataframe /
# we rename this to area_propsearch
key_information_df_column_rename = {'area': 'area_propsearch'}
key_information_df.rename(columns=key_information_df_column_rename, inplace=True)

# %%
# shorted the info caption for the last photo taken of the project, to remove the developer name and keep the date
import re

def shorten_photo_caption(caption):
    # input: caption from caption row
    # output: trimmed caption without the tower name
    # e.g.: Waterfall Tower, construction update May 2021. --> update May 2021
    short_caption = re.search('construction (.*)', caption)
    # check regex found a match, else return original caption
    if short_caption != None:
        return short_caption.group(1).replace('\"', '').replace('.', '')
    return caption
 
# apply shorten_photo_caption on the last_photo_df caption column
last_photo_df.caption = last_photo_df.caption.apply(shorten_photo_caption);

# %%
# concat all table dfs 
compound_info_df = pd.concat(compound_df_list, axis=1)

# %%
# concat concat table df with main df
flat_df_bbay_udev = pd.concat([complete_df, compound_info_df], axis=1)

# %%
# drop 'tables' and 'last_photo_update' columns since these have been flattened into new columns
# before, they used to be compressed into dictionaries in these columns
flat_df_bbay_udev.drop(columns=['tables', 'last_photo_update'], inplace=True)

# %%
flat_df_bbay_udev
# Out:
#              area         sub_area  \
# 96   Business Bay     Business Bay
# 98   Business Bay     Business Bay
# 99   Business Bay     Business Bay
# 108  Business Bay     Business Bay
# 110  Business Bay     Business Bay
# 118  Business Bay     Business Bay
# 121  Business Bay     Business Bay
# 133  Business Bay     Business Bay
# 134  Business Bay     Business Bay
# 140  Business Bay     Business Bay
# 144  Business Bay  Al Habtoor City
# 158  Business Bay     Business Bay
# 167  Business Bay     Business Bay
# 173  Business Bay     Business Bay
# 177  Business Bay     Business Bay
# 178  Business Bay     Business Bay
# 185  Business Bay     Business Bay
# 189  Business Bay     Business Bay
# 192  Business Bay     Business Bay
# 193  Business Bay     Business Bay
# 196  Business Bay     Business Bay
# 209  Business Bay     Business Bay
# 219  Business Bay     Business Bay
# 233  Business Bay     Business Bay
# 243  Business Bay     Business Bay
# 285  Business Bay     Business Bay
# 291  Business Bay     Business Bay
# 295  Business Bay     Business Bay
# 296  Business Bay     Business Bay
# 298  Business Bay     Business Bay
# 299  Business Bay     Business Bay
# 303  Business Bay     Business Bay
# 306  Business Bay     Business Bay
# 312  Business Bay     Business Bay
#
#                                          project             status  \
# 96               Millennium Binghatti Residences  Under development
# 98                                    Moon Tower  Under development
# 99                      Mövenpick Hotel & Living  Under development
# 108                     Nobles Residential Tower  Under development
# 110                            Marble Arch Tower  Under development
# 118                           Mama Shelter Dubai  Under development
# 121                                Lillian Tower  Under development
# 133                        AG Tower Business Bay  Under development
# 134                              Ahad Residences  Under development
# 140           Paramount Tower Hotel & Residences  Under development
# 144                                   Amna Tower  Under development
# 158                 Kingston Towers Business Bay  Under development
# 167                                Sky Bay Hotel  Under development
# 173                               Safeer Tower 3  Under development
# 177                Ritz Carlton Hotel Apartments  Under development
# 178                                Reva by Damac  Under development
# 185                      Ramee Grand Hotel & Spa  Under development
# 189               SRG Holding Hotel Business Bay  Under development
# 192                       Kempinski Business Bay  Under development
# 193                                  Kasco Tower  Under development
# 196                                        J One  Under development
# 209                              The Court Tower  Under development
# 219                   The One Hotel Business Bay  Under development
# 233                       Dorchester Hotel Dubai  Under development
# 243                                Dolphin Tower  Under development
# 285                               Bayz by Danube  Under development
# 291                          Corporate Bay Tower  Under development
# 295                          Tiara United Towers  Under development
# 296  Commercial & Residential Tower Plot 3460763  Under development
# 298                                   Zada Tower  Under development
# 299                                  Yotel Dubai  Under development
# 303                               West Bay Tower  Under development
# 306                              Waterfall Tower  Under development
# 312                                Vera by Damac  Under development
#
#                                                    url  \
# 96   https://propsearch.ae/dubai/millennium-binghat...
# 98              https://propsearch.ae/dubai/moon-tower
# 99   https://propsearch.ae/dubai/movenpick-hotel-li...
# 108  https://propsearch.ae/dubai/nobles-residential...
# 110      https://propsearch.ae/dubai/marble-arch-tower
# 118     https://propsearch.ae/dubai/mama-shelter-dubai
# 121          https://propsearch.ae/dubai/lillian-tower
# 133  https://propsearch.ae/dubai/ag-tower-business-bay
# 134        https://propsearch.ae/dubai/ahad-residences
# 140  https://propsearch.ae/dubai/paramount-tower-ho...
# 144             https://propsearch.ae/dubai/amna-tower
# 158  https://propsearch.ae/dubai/kingston-towers-bu...
# 167          https://propsearch.ae/dubai/sky-bay-hotel
# 173         https://propsearch.ae/dubai/safeer-tower-3
# 177  https://propsearch.ae/dubai/ritz-carlton-hotel...
# 178          https://propsearch.ae/dubai/reva-by-damac
# 185  https://propsearch.ae/dubai/ramee-grand-hotel-spa
# 189  https://propsearch.ae/dubai/srg-holding-hotel-...
# 192  https://propsearch.ae/dubai/kempinski-business...
# 193            https://propsearch.ae/dubai/kasco-tower
# 196                  https://propsearch.ae/dubai/j-one
# 209        https://propsearch.ae/dubai/the-court-tower
# 219  https://propsearch.ae/dubai/the-one-hotel-busi...
# 233  https://propsearch.ae/dubai/dorchester-hotel-d...
# 243          https://propsearch.ae/dubai/dolphin-tower
# 285         https://propsearch.ae/dubai/bayz-by-danube
# 291    https://propsearch.ae/dubai/corporate-bay-tower
# 295    https://propsearch.ae/dubai/tiara-united-towers
# 296  https://propsearch.ae/dubai/commercial-residen...
# 298             https://propsearch.ae/dubai/zada-tower
# 299            https://propsearch.ae/dubai/yotel-dubai
# 303         https://propsearch.ae/dubai/west-bay-tower
# 306        https://propsearch.ae/dubai/waterfall-tower
# 312          https://propsearch.ae/dubai/vera-by-damac
#
#                    coordinates                             developer  \
# 96      25°10 51"N 55°16 8.8"E                  Binghatti Developers
# 98     25°11 3.5"N 55°17 5.1"E       Arabia Group Investment Limited
# 99   25°11 19.6"N 55°16 13.1"E                       SAAS Properties
# 108   25°11 4.5"N 55°17 24.8"E                      Tiger Properties
# 110  25°10 46.8"N 55°15 53.9"E                                   NaN
# 118  25°10 48.3"N 55°16 18.9"E    Kappa Acca Real Estate Development
# 121  25°11 14.3"N 55°15 45.4"E                     Marya Investments
# 133   25°10 47.6"N 55°16 8.9"E               Arabian Gulf Properties
# 134    25°11 12"N 55°15 57.6"E            Mercury Investment Holding
# 140  25°11 36.3"N 55°15 55.3"E                      Damac Properties
# 144  25°10 57.2"N 55°15 20.6"E                      Al Habtoor Group
# 158  25°10 49.8"N 55°16 42.1"E                              Kingston
# 167   25°10 41.3"N 55°16 4.7"E                       The First Group
# 173  25°10 47.6"N 55°16 40.4"E       Al Seeb Real Estate Development
# 177    25°11 4.7"N 55°17 6.4"E    Kappa Acca Real Estate Development
# 178    25°11 16"N 55°16 59.1"E                      Damac Properties
# 185  25°11 17.2"N 55°16 53.6"E                           Ramee Group
# 189     25°11 6"N 55°17 23.1"E                   SRG Holding Limited
# 192  25°10 54.3"N 55°16 45.1"E            Seastar Properties Limited
# 193    25°11 0.9"N 55°17 2.5"E                       Ahmed Al Janabi
# 196     25°11 10.3"N 55°17 0"E                   RKM Real Estate LLC
# 209   25°11 4.8"N 55°15 31.8"E                       Tanmiyat Global
# 219  25°10 44.3"N 55°16 32.8"E                       The First Group
# 233  25°11 16.3"N 55°17 17.6"E               Sky Palaces Real Estate
# 243  25°10 59.1"N 55°16 59.4"E                                   NaN
# 285  25°10 50.5"N 55°16 45.5"E     Danube Properties Development LLC
# 291   25°11 5.3"N 55°15 40.1"E  Goldline Real Estate Development LLC
# 295  25°11 19.8"N 55°15 35.7"E                    Zabeel Investments
# 296  25°11 25.9"N 55°17 27.7"E                                   NaN
# 298     25°11 4.6"N 55°15 42"E                      Damac Properties
# 299  25°11 15.8"N 55°15 29.7"E           Dubai Investment Properties
# 303     25°11 5"N 55°15 48.1"E         Orion Real Estate Development
# 306    25°10 51"N 55°15 57.3"E                 Faisal Muhsen Barakat
# 312  25°11 13.2"N 55°16 57.8"E                      Damac Properties
#
#                         architectural_consultant  \
# 96                          Eng. Adnan Saffarini
# 98   Chawla Architectural & Consulting Engineers
# 99                   National Engineering Bureau
# 108  LACASA Architects & Engineering Consultants
# 110                            DXB Design Studio
# 118                   Franklin Azzi Architecture
# 121                                          NaN
# 133                   CVTEC Consulting Engineers
# 134                                VX Architects
# 140  LACASA Architects & Engineering Consultants
# 144                         WS Atkins & Partners
# 158                          Canadian Consultant
# 167               Alajmi Engineering Consultants
# 173                  National Engineering Bureau
# 177                  National Engineering Bureau
# 178                               U+A Architects
# 185                        Archgroup Consultants
# 189        ERGA Progress Engineering Consultants
# 192                  National Engineering Bureau
# 193                 Next Engineering Consultants
# 196               QHC Architects & Engineers LLC
# 209             Al Hazmi & Associates Consultant
# 219                Engineering Consultants Group
# 233                            Foster + Partners
# 243         Arab Experts Engineering Consultants
# 285                  National Engineering Bureau
# 291            Em Square Engineering Consultants
# 295                                          NaN
# 296                        Art Consultants Dubai
# 298                           Kieferle & Partner
# 299                                          NaN
# 303                  National Engineering Bureau
# 306                            Nàbito Architects
# 312                               U+A Architects
#
#                                            contractor  \
# 96         Granada Europe Engineering Contracting Co.
# 98                                                NaN
# 99                                   Kele Contracting
# 108           Tiger International General Contracting
# 110              Modern Executive Systems Contracting
# 118                       CRC Engineering Company LLC
# 121                                               NaN
# 133   Beijing Emirates International Construction Co.
# 134                   Evan Lim Penta Construction LLC
# 140                                               NaN
# 144                                               NaN
# 158                             Gulf Asia Contracting
# 167                         Al Habbai Contracting LLC
# 173                         Rose City Contracting LLC
# 177                                   AIC Contracting
# 178                              Arabtec Construction
# 185                         Delta Al Wadi Contracting
# 189                         Al Habbai Contracting LLC
# 192                                               NaN
# 193                         Sumer Contracting Company
# 196                            Ali & Sons Contracting
# 209                                               NaN
# 219                   China Railway 18th Bureau Group
# 233                             Roberts Constructions
# 243              Modern Executive Systems Contracting
# 285                            RAQ Contracting Co LLC
# 291  China State Construction Engineering Corporation
# 295                                               NaN
# 296                             Gulf Asia Contracting
# 298                         Transemirates Contracting
# 299                                               NaN
# 303               Gulf Technical Construction Company
# 306                                               NaN
# 312                              Arabtec Construction
#
#                          piling_contractor  ... total_units  \
# 96                                     NaN  ...         230
# 98                                     NaN  ...         255
# 99                                     NaN  ...         403
# 108                                    NaN  ...         549
# 110                   Geo Foundation Group  ...         NaN
# 118                   TMF Euro Foundations  ...         201
# 121                                    NaN  ...         583
# 133                                    NaN  ...         437
# 134                                    NaN  ...         NaN
# 140                                    NaN  ...         826
# 144                                    NaN  ...         537
# 158                  Delta Foundations Co.  ...         NaN
# 167                                    NaN  ...         440
# 173                                    NaN  ...         NaN
# 177                                    NaN  ...         NaN
# 178                National Piling Company  ...         NaN
# 185                  Delta Foundations Co.  ...         NaN
# 189                                    NaN  ...         NaN
# 192                                    NaN  ...         240
# 193                                    NaN  ...         NaN
# 196                                    NaN  ...         347
# 209                                    NaN  ...         NaN
# 219           Stromek Emirates Foundations  ...         492
# 233                     NSCC International  ...         NaN
# 243                                    NaN  ...         330
# 285                                    NaN  ...         456
# 291                                    NaN  ...         NaN
# 295                                    NaN  ...         NaN
# 296  Edrafor Piling And Special Foundation  ...         NaN
# 298                National Piling Company  ...         699
# 299                                    NaN  ...         565
# 303                   Geo Foundation Group  ...         252
# 306                                    NaN  ...         NaN
# 312                National Piling Company  ...         NaN
#
#                                             unit_types floors_below_ground  \
# 96   113 studios58 one-bedroom apartments59 two-bed...                 NaN
# 98   StudiosOne-bedroom apartmentsTwo-bedroom apart...                 NaN
# 99                                                 NaN                 NaN
# 108  278 one-bedroom apartments239 two-bedroom apar...                   2
# 110                                                NaN                 NaN
# 118                                                NaN                   3
# 121                                                NaN                   3
# 133  One-bedroom apartmentsTwo-bedroom apartmentsTh...                 NaN
# 134                                                NaN                   5
# 140                                                NaN                 NaN
# 144  One-bedroom apartmentsTwo-bedroom apartmentsTh...                 NaN
# 158                                                NaN                   2
# 167                                    440 hotel rooms                 NaN
# 173                                                NaN                   1
# 177                                                NaN                 NaN
# 178                                                NaN                 NaN
# 185                                                NaN                   4
# 189                                                NaN                   1
# 192                                    240 hotel rooms                 NaN
# 193                                                NaN                   2
# 196                                                NaN                 NaN
# 209                                                NaN                 NaN
# 219                                    492 hotel rooms                   2
# 233                                                NaN                   2
# 243                                    330 hotel rooms                 NaN
# 285  264 studios120 one-bedroom apartments48 two-be...                 NaN
# 291                                                NaN                   5
# 295                                                NaN                 NaN
# 296                                                NaN                   2
# 298                         699 one-bedroom apartments                   4
# 299                                    565 hotel rooms                 NaN
# 303  24 studios78 one-bedroom apartments120 two-bed...                   4
# 306                                                NaN                 NaN
# 312  StudiosOne-bedroom apartmentsTwo-bedroom apart...                 NaN
#
#                       height   date_launched estimated_handover_date  \
# 96                       NaN      March 2018                 Q4 2019
# 98                       NaN            2007                     NaN
# 99                       NaN             NaN                 Q4 2016
# 108                      NaN  September 2017                     NaN
# 110                      NaN             NaN                     NaN
# 118                      NaN        May 2017                    2020
# 121                      NaN            2007                    2016
# 133                      NaN            2015                     NaN
# 134                      NaN            2017                     NaN
# 140                      NaN  September 2014                 Q3 2019
# 144  307 metres (1,007 feet)             NaN                     NaN
# 158                      NaN            2018                     NaN
# 167                      NaN             NaN                     NaN
# 173                      NaN            2018                     NaN
# 177                      NaN         Q1 2021                     NaN
# 178                      NaN    January 2018                     NaN
# 185                      NaN            2017                     NaN
# 189                      NaN            2018                     NaN
# 192                      NaN             NaN                     NaN
# 193                      NaN            2018                     NaN
# 196                      NaN     August 2017                     NaN
# 209                      NaN            2005                     NaN
# 219                      NaN       July 2016                     NaN
# 233                      NaN            2017                    2020
# 243                      NaN             NaN                     NaN
# 285                      NaN        May 2017                     NaN
# 291                      NaN             NaN                     NaN
# 295                      NaN             NaN                     NaN
# 296                      NaN             NaN                     NaN
# 298                      NaN      April 2019                     NaN
# 299                      NaN             NaN                 Q3 2018
# 303                      NaN             NaN                    2009
# 306                      NaN            2017                     NaN
# 312                      NaN       June 2016                    2018
#
#     construction_started revised_estimated_handover_date              caption  \
# 96                  2018                             NaN      update May 2021
# 98                  2009                         Q4 2016      update May 2021
# 99                  2015                             NaN      update May 2021
# 108                 2019                             NaN      update May 2021
# 110                 2019                             NaN      update May 2021
# 118                 2018                             NaN      update May 2021
# 121                  NaN                             NaN      update May 2021
# 133                 2016                             NaN      update May 2021
# 134                 2018                             NaN      update May 2021
# 140                 2015                             NaN      update May 2021
# 144                  NaN                             NaN     update July 2020
# 158                 2019                             NaN      update May 2021
# 167                 2016                             NaN      update May 2021
# 173                 2019                             NaN      update May 2021
# 177                  NaN                             NaN       site signboard
# 178                 2018                             NaN      update May 2021
# 185                 2018                             NaN      update May 2021
# 189                 2018                             NaN      update May 2021
# 192                  NaN                             NaN      update May 2021
# 193                 2018                             NaN      update May 2021
# 196                 2017                             NaN      update May 2021
# 209                 2006                             NaN      update May 2021
# 219                 2017                             NaN      update May 2021
# 233                 2017                             NaN      update May 2021
# 243                  NaN                             NaN  update January 2021
# 285                 2018                             NaN      update May 2021
# 291                 2007                             NaN  update January 2021
# 295                 2006                             NaN      update May 2021
# 296                 2019                             NaN      update May 2021
# 298                  NaN                             NaN      update May 2021
# 299          August 2016                             NaN      update May 2021
# 303         October 2018                   December 2019       site signboard
# 306                 2017                             NaN      update May 2021
# 312                  NaN                             NaN      update May 2021
#
#                                              photo_url
# 96   https://static.propsearch.ae/dubai-locations/m...
# 98   https://static.propsearch.ae/dubai-locations/m...
# 99   https://static.propsearch.ae/dubai-locations/m...
# 108  https://static.propsearch.ae/dubai-locations/n...
# 110  https://static.propsearch.ae/dubai-locations/m...
# 118  https://static.propsearch.ae/dubai-locations/m...
# 121  https://static.propsearch.ae/dubai-locations/l...
# 133  https://static.propsearch.ae/dubai-locations/a...
# 134  https://static.propsearch.ae/dubai-locations/a...
# 140  https://static.propsearch.ae/dubai-locations/p...
# 144  https://static.propsearch.ae/dubai-locations/a...
# 158  https://static.propsearch.ae/dubai-locations/k...
# 167  https://static.propsearch.ae/dubai-locations/s...
# 173  https://static.propsearch.ae/dubai-locations/s...
# 177  https://static.propsearch.ae/dubai-locations/r...
# 178  https://static.propsearch.ae/dubai-locations/r...
# 185  https://static.propsearch.ae/dubai-locations/r...
# 189  https://static.propsearch.ae/dubai-locations/s...
# 192  https://static.propsearch.ae/dubai-locations/k...
# 193  https://static.propsearch.ae/dubai-locations/k...
# 196  https://static.propsearch.ae/dubai-locations/j...
# 209  https://static.propsearch.ae/dubai-locations/t...
# 219  https://static.propsearch.ae/dubai-locations/t...
# 233  https://static.propsearch.ae/dubai-locations/d...
# 243  https://static.propsearch.ae/dubai-locations/d...
# 285  https://static.propsearch.ae/dubai-locations/b...
# 291  https://static.propsearch.ae/dubai-locations/c...
# 295  https://static.propsearch.ae/dubai-locations/t...
# 296  https://static.propsearch.ae/dubai-locations/c...
# 298  https://static.propsearch.ae/dubai-locations/z...
# 299  https://static.propsearch.ae/dubai-locations/y...
# 303  https://static.propsearch.ae/dubai-locations/w...
# 306  https://static.propsearch.ae/dubai-locations/w...
# 312  https://static.propsearch.ae/dubai-locations/v...
#
# [34 rows x 32 columns]

# %% [markdown]
# #### Save progress to cvs: Business Bay Under Development (flattened df)
#
# Save progess into csv.  This Df is actionable and ready to be used.  All it needs is contact details.

# %%
flat_df_bbay_udev.to_csv('bbay_udev_flat.csv')

# %% [markdown]
# ## Block code into functions to run for all areas

# %% [markdown]
# ### Define main

# %%
# main function
def process_scrap_output(project_status, project_area, df):
    
    # get df window by status and area
    df = df[df.status == project_status]
    df = df[df.area == project_area]
    
    # scrap links in df and build a dictionary with all info
    print('scrapping links')
    scrapped_dict = scrap_df_to_dict(df)
    
    # convert the scrapped dict into a dataframe and concat it with main df
    print('merging scrap with main')
    merged_df = merge_scrapped_dict_to_df(df, scrapped_dict)
    
    # apply rename_table_keys function to rename keys in tables column for easy referencing
    # this removes the project name from the key strings in each dictionary
    print('renaming table keys')
    merged_df.tables.apply(rename_table_keys)
    
    # flatten the info contained in merged_df in dictionaries, into columns on a new df
    print('flattening dfs')
    compound_df = flatten_data_df(merged_df)

    # concat concat table df with main df
    flat_df = pd.concat([merged_df, compound_df], axis=1)

    # drop 'tables' and 'last_photo_update' columns since these have been flattened into new columns
    # before, they used to be compressed into dictionaries in these columns
    flat_df.drop(columns=['tables', 'last_photo_update'], inplace=True)
    
    print('returning flat df')
    
    return flat_df

# %% [markdown]
# ### Auxiliary functions used in main

# %%
import re

def get_last_photo_update(soup):
    # get string and link of last project photo update to check progress
    construction_updates = soup.find(id='jump-to-construction-updates')
    gallery = construction_updates.find('div', class_='fotorama ps-gallery-portrait')
    raw_caption = gallery.find('a')

    raw_caption = str(raw_caption)
    caption = re.search('data-caption="(.*) Image &amp;copy', raw_caption)
    caption = caption.group(1).replace('\"', '')
    photo_url = re.search('data-full=(.*) href=', raw_caption)
    photo_url = photo_url.group(1).replace('\"', '')
    return caption, photo_url

def scrap_df_to_dict(scrap_df):
    # input: a dataframe with links to scrap from propsearch
    # output: dictionary with scraped data
    # set bounds for urls to scrap
    url_idx_start = 0
    url_idx_end = len(scrap_df) + 1
    # construct an iterable with the original index and the url
    url_list = zip(list(scrap_df.link.iloc[url_idx_start:url_idx_end].index), 
                   list(scrap_df.link.iloc[url_idx_start:url_idx_end]))
    # instantiate dic to hold scrapped data
    scrapped_dict = {}
    # iterate over a list of urls
    for url_key, url in url_list:
        # cast url_key as str to index the dictionary
        url_key = str(url_key)
        # set request header with appropriate permissions
        headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}
        # request url data
        r = requests.get(url, headers=headers)#, proxies=proxies)
        # get content
        content = r.content
        # parse content
        soup = BeautifulSoup(content, "html.parser")

        # add this entry to dictionary, using the same key as in the original dataframe index
        scrapped_dict[url_key] = {}
        # save the url
        scrapped_dict[url_key]['url'] = url
        # add space to save each table with info
        scrapped_dict[url_key]['tables'] = {}

        # get coordinates
        coordinates_div = soup.find('div', attrs={'class':'ps-guide-sub-subheading'})
        coordinates = coordinates_div.text.strip().replace('place', '').replace('\'', ' ')
        # add coordinates to dict
        scrapped_dict[url_key]['coordinates'] = coordinates

        # get las photo update
        try:
            caption, photo_url = get_last_photo_update(soup)
            scrapped_dict[url_key]['last_photo_update'] = {'caption': caption, 'photo_url': photo_url}
        except:
            print('Failed to get photo update for: {}'.format(url))
            pass

        # get tables with contents
        kv_list = soup.findAll('div', class_='ps-kv-list')
        # iterate through tables
        for k in kv_list:
            # get table title
            # some tables won't have a title, which we ignore
            try:
                title = k.find(class_='ps-kv-list-title').text.lower().replace(' ', '-')
            except AttributeError as a_err:
                print('Error on table for: {}'.format(url))
                continue
            # instantiate dict for each title
            scrapped_dict[url_key]['tables'][title] = {}
            # get table content
            contents = k.findAll('div', class_='grid-x')
            # iterate through table content
            for content in contents:
                entry = content.text.strip().split('\n')
                scrapped_dict[url_key]['tables'][title][entry[0]] = entry[1]
                
    return scrapped_dict

def merge_scrapped_dict_to_df(df, scrapped_dict):
    # input: df: main df with links and project area details
    # input: scrapped_dict: dict with granular details per project
    # output: merged_df: concat main df with df created with scrapped_dict
    
    # create df from scrapped dictionary, transpose to get the numbers as index
    scrapped_df = pd.DataFrame(scrapped_dict).T
    # scrapped_dict dataframe will have an 'object' type index, whereas the df is 'int64'
    # recast scrapped_dict index to match df, otherwise the concatenation operation returns nan values
    scrapped_df.index = scrapped_df.index.astype('int64')
    # merge with df
    merged_df = pd.concat([df, scrapped_df], axis=1)
    # drop duplicate url-link column
    merged_df.drop(columns=['link'], inplace=True)
    return merged_df
    
    
# function that renames the keys in the tables to remove the project name
def rename_table_keys(table):
    # Input: table: contents of each rown on the tables column of the dataframe
    # eg transform: 'mama-shelter-dubai-key-information' -->  #'key-information'
    # extract all available keys
    key_ids = list(table)
    # iterate over keys and rename them to remove the project name from each and make them universal keys
    for key_id in key_ids:
        if 'key-information' in key_id:
            table['key-information'] = table.pop(key_id)
        elif 'companies-associated' in key_id:
            table['companies-associated'] = table.pop(key_id)
        elif  'milestones' in key_id:
            table['milestones'] = table.pop(key_id)
    return table

# lower case column name and use underscore as space separator
def lower_dash_column_rename(column_list):
    # transform to lower case and use undesrcore as word separator
    return [col.strip().lower().replace(' ', '_') for col in column_list]

# shorted the info caption for the last photo taken of the project, to remove the developer name and keep the date
def shorten_photo_caption(caption):
    # input: caption from caption row
    # output: trimmed caption without the tower name
    # e.g.: Waterfall Tower, construction update May 2021. --> update May 2021
    try:
        short_caption = re.search('construction (.*)', caption)
    except:
        print('error reading caption: {}'.format(caption))
        return caption
    # check regex found a match, else return original caption
    if short_caption != None:
        return short_caption.group(1).replace('\"', '').replace('.', '')
    return caption

def flatten_data_df(df):
    # since scrapped data was saved in dictionaries and placed in cells in the df, we wish to/
    # extract those field and convert them into columns, this function accomplishes that
    # input: df with project data and scrapped data which is saved as dictionaries within the df
    # output: a df that contains all data but as a flat df, no more dictionaries within
    
    # For each table with data, extract the data into a dictionary which we will use to create dataframes
    # each dataframe contains all table info for each row, which we will concatenate to the global dataframe
    companies_associated = {}
    key_information = {}
    milestones = {}
    last_photo = {}
    for index, row in df.iterrows():
        companies_associated[index] = row.tables.get('companies-associated', np.nan)
        key_information[index] = row.tables.get('key-information', np.nan)
        milestones[index] = row.tables.get('milestones', np.nan)
        last_photo[index] = row.last_photo_update

    # build dataframes from the dictionaries created
    companies_associated_df = pd.DataFrame(companies_associated).T
    key_information_df = pd.DataFrame(key_information).T
    try:
        milestones_df = pd.DataFrame(milestones).T
    except ValueError:
        print('issue creating milestones_df: {}'.format(ValueError))
        milestones_df = pd.DataFrame()
    last_photo_df = pd.DataFrame(last_photo).T

    # cluster all dataframes into a list for easy access
    compound_df_list = [companies_associated_df, key_information_df, milestones_df, last_photo_df]

    # reaname columns
    for comp_df in compound_df_list:
        comp_df.columns = lower_dash_column_rename(comp_df.columns)

    # since key_information_df has an area column which clashes in name with the original dataframe /
    # we rename this to area_propsearch
    key_information_df_column_rename = {'area': 'area_propsearch'}
    key_information_df.rename(columns=key_information_df_column_rename, inplace=True)

    # apply shorten_photo_caption on the last_photo_df caption column
    last_photo_df.caption = last_photo_df.caption.apply(shorten_photo_caption);

    # concat all table dfs 
    compound_info_df = pd.concat(compound_df_list, axis=1)

    return compound_info_df

# %% [markdown]
# ### Define search areas and load data
#
# Load data with links to scrap and specify project status and project area
#
# Requires user input

# %%
# set source file name
source_file_path = 'towers_df.csv'

# set target areas and project status
project_area = 'Business Bay'
project_status = 'Under development'

### DO not change variables below this line
# set output file name
output_file_path = project_area.lower().replace(' ', '_') + '_' + project_status.lower().replace(' ', '_') + '.csv'

# read source file
df = pd.read_csv(source_file_path)

# %% [markdown]
# ### Run main processing
# Outputs csv ready to be used

# %%
flat_df = process_scrap_output(project_status, project_area, df)
# Out:
# Error on table for: https://propsearch.ae/dubai/mama-shelter-dubai
# Error on table for: https://propsearch.ae/dubai/amna-tower
# Error on table for: https://propsearch.ae/dubai/dorchester-hotel-dubai
# Error on table for: https://propsearch.ae/dubai/zada-tower

# %% [markdown]
# ### Save output to csv

# %%
flat_df.to_csv(os.path.join('output', output_file_path), index=False)

# %% [markdown]
# ## Create output files for multiple areas

# %%
# set target areas and project status
project_area = 'Motor City'
project_status = 'Under development'

### DO not change variables below this line
# set output file name
output_file_path = project_area.lower().replace(' ', '_') + '_' + project_status.lower().replace(' ', '_') + '.csv'

# set source file name
source_file_path = 'towers_df.csv'
# read source file
df = pd.read_csv(source_file_path)

# run main
flat_df = process_scrap_output(project_status, project_area, df)

# save output
flat_df.to_csv(os.path.join('output', output_file_path), index=False)
# Out:
# scrapping links
# merging scrap with main
# renaming table keys
# flattening dfs
# issue creating milestones_df: <class 'ValueError'>
# returning flat df

# %% [markdown]
# ### Describe data to see what to extract

# %%
df = pd.read_csv(source_file_path)

# %%
# project count by status type
df.status.value_counts()
# Out:
# Complete                             934
# Under development                    277
# Under development (Cancelled)        136
# Under development (On hold)          134
# Planned                               47
# Envisioned                            22
# Under development (In progress)       15
# Planned (Cancelled)                    5
# Under development (Progress slow)      3
# Demolished                             2
# Complete (Handover underway)           1
# Name: status, dtype: int64

# %%
ud_df = df[df.status == 'Under development']

# %%
ud_df.area.value_counts()
# Out:
# Jumeirah Village Circle      97
# Business Bay                 34
# Arjan                        32
# Jumeirah Village Triangle    22
# Downtown                     18
# Dubai Creek Harbour          17
# Palm Jumeirah                16
# Sobha Hartland               11
# Dubai Hills Estate           10
# Dubai Marina                  9
# Sports City                   7
# Jumeirah Lakes Towers         2
# Motor City                    2
# Name: area, dtype: int64

# %% [markdown]
# Busines Bay
# Jumeirah Village Circle
# Downtown

# %% [markdown]
# Jumeirah Village Circle      97 done
# Business Bay                 34 done
# Arjan                        32 done
# Jumeirah Village Triangle    22 done
# Downtown                     18 done
# Dubai Creek Harbour          17 done
# Palm Jumeirah                16 done
# Sobha Hartland               11 done
# Dubai Hills Estate           10 done
# Dubai Marina                  9 done
# Sports City                   7 done
# Jumeirah Lakes Towers         2 done
# Motor City

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1155-87017fdebad7> in <module>
# ----> 1 df.name
#
# ~/opt/miniconda3/envs/jupyter_sandbox_venv/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'name'
